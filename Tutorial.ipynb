# %% [markdown]
# # Introduction
#
# This is a brief introduction to the [refractivesqlite package](https://github.com/HugoGuillen/refractiveindex.info-sqlite) developed by [Hugo Guillén](https://github.com/HugoGuillen). This package is a wrapper in Python 3 for the database of optical constants [refractiveindex.info](http://refractiveindex.info/) developed by [Mikhail Polyanskiy](https://github.com/polyanskiy).
#
# For better visualization, this tutorial can be downloaded as an interactive Jupyter Notebook [here](https://github.com/HugoGuillen/refractiveindex.info-sqlite/blob/master/Tutorial.ipynb).
#
# ## Features
# The principal functionality of this package is to allow offline/programmatically queries to the database such as:
# - Create a local SQLite database from the refractiveindex yml folder.
# - Create a local SQLite database from the refractiveindex.zip url.
# - Search the local database pages by approximate or exact terms.
# - Search material data (refractiveindex, extinctioncoefficient) by intervals.
# - Execute custom SQL queries on the database.
# - Export material data (refractiveindex, extinctioncoefficient) to numpy arrays or csv files.
# - Get data (refractiveindex, extinctioncoefficient) at specified wavelengths.
#
# ## Scheme
# The package creates a database with the [following scheme](https://github.com/HugoGuillen/refractiveindex.info-sqlite/blob/master/ER.PNG).
#
# ![Scheme](ER.PNG "Scheme")
#
# The table ``pages`` contains information about the materials; ``refractiveindex``  and ``extcoeff`` are self explanatory.

# %% [markdown]
# # Features
# ## Create the database
#
# Note: once created, you don't need to create the DB again!
# In both methods you can specify the interpolation_points for the case when *n* is expressed as a formula and *k* is not defined.

# %% [markdown]
# ### From url
# You can use the default database, or specify the link of the version you want to load (See 2.1.3).
#
# *Note: you may see some LOG warnings, that's perfectly normal.*

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
db = DB.Database(dbpath)
db.create_database_from_url()
# Out:
# Database file found at refractive.db
# Making request to https://refractiveindex.info/download/database/rii-database-2019-02-11.zip
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# c:\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# c:\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# c:\python39\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# c:\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# c:\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# c:\python39\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18144/1303717323.py in <module>
#       3 dbpath = "refractive.db"
#       4 db = DB.Database(dbpath)
# ----> 5 db.create_database_from_url()
#
# ~\Documents\Python\refractive_index_calcs\refractivesqlite\dboperations.py in create_database_from_url(self, riiurl, interpolation_points)
#      54         :param interpolation_points: The number of interpolation_points to use
#      55         '''
# ---> 56         Database.DownloadRIIzip(riiurl=riiurl)
#      57         self.create_database_from_folder(
#      58             "database", interpolation_points=interpolation_points)
#
# ~\Documents\Python\refractive_index_calcs\refractivesqlite\dboperations.py in DownloadRIIzip(outputfolder, riiurl)
#     372         import io
#     373         print("Making request to", riiurl)
# --> 374         r = requests.get(riiurl)
#     375         if r.ok:
#     376             print("Downloaded and extracting...")
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\.virtualenvs\refractive_index_calcs-u0Cna5Xy\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %% [markdown]
# ### Check URL version

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
db = DB.Database(dbpath)
db.check_url_version()
# Out:
# Database file found at refractive.db
# https://refractiveindex.info/download/database/rii-database-2019-02-11.zip

# %% [markdown]
# ### Create from a custom URL
# You can find the .zip file of a version [here](http://refractiveindex.info/download.php). For example, to load the version 2016-05-25:

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
db = DB.Database(dbpath)
db.create_database_from_url(riiurl="https://refractiveindex.info/download/database/rii-database-2019-02-11.zip")
# Out:
# Database file found at refractive.db
# Making request to https://refractiveindex.info/download/database/rii-database-2019-02-11.zip
# Downloaded and extracting...
# Wrote /database from https://refractiveindex.info/download/database/rii-database-2019-02-11.zip
# LOG: 84,main,BaB2O4,Tamosauskas-o : 'charmap' codec can't decode byte 0x8d in position 207: character maps to <undefined>
# LOG: 85,main,BaB2O4,Tamosauskas-e : 'charmap' codec can't decode byte 0x8d in position 207: character maps to <undefined>
# LOG: 359,main,Al2O3,Boidin : 'charmap' codec can't decode byte 0x8d in position 201: character maps to <undefined>
# LOG: 575,main,Si,Sik-25C : 'charmap' codec can't decode byte 0x81 in position 205: character maps to <undefined>
# LOG: 576,main,Si,Sik-250C : 'charmap' codec can't decode byte 0x81 in position 205: character maps to <undefined>
# LOG: 577,main,Si,Sik-500C : 'charmap' codec can't decode byte 0x81 in position 205: character maps to <undefined>
# LOG: 578,main,Si,Sik-700C : 'charmap' codec can't decode byte 0x81 in position 205: character maps to <undefined>
# LOG: 579,main,Si,Sik-850C : 'charmap' codec can't decode byte 0x81 in position 205: character maps to <undefined>
# ***Wrote SQLite DB on  refractive.db

# %% [markdown]
# ### From local yml folder

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
ymlpath = "database"
db = DB.Database(dbpath)
db.create_database_from_folder(ymlpath,interpolation_points=200)
# Out:
# Database file not found.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8220/1308569292.py in <module>
#       4 ymlpath = "database"
#       5 db = DB.Database(dbpath)
# ----> 6 db.create_database_from_folder(ymlpath,interpolation_points=200)
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in create_database_from_folder(self, yml_database_path, interpolation_points)
#      40         :param interpolation_points: The number of interpolation_points to use
#      41         '''
# ---> 42         create_sqlite_database(yml_database_path,
#      43                                self.db_path,
#      44                                interpolation_points=interpolation_points)
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in create_sqlite_database(refractiveindex_db_path, new_sqlite_db, interpolation_points)
#     447     conn.commit()
#     448     conn.close()
# --> 449     _populate_sqlite_database(refractiveindex_db_path,
#     450                               new_sqlite_db,
#     451                               interpolation_points=interpolation_points)
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in _populate_sqlite_database(refractiveindex_db_path, new_sqlite_db, interpolation_points)
#     462     :interpolation_points=100: The number of interpolation points
#     463     '''
# --> 464     entries = extract_entry_list(refractiveindex_db_path)
#     465     conn = sqlite3.connect(new_sqlite_db)
#     466     c = conn.cursor()
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in extract_entry_list(db_path)
#     391     library_yml_path = os.path.join(referencePath,
#     392                                     os.path.normpath("library.yml"))
# --> 393     with open(library_yml_path, "r") as f:
#     394         catalog = yaml.safe_load(f)
#     395     for sh in catalog:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database\\library.yml'

# %% [markdown]
# ### Load existing database

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
db = DB.Database(dbpath)
# Out:
# Database file found at refractive.db

# %% [markdown]
# ## Searches

# %% [markdown]
# ### List all pages

# %%
db.search_pages()
# Out:
# 2706 results found.
# pageid	shelf	book	page	filepath	hasrefractive	hasextinction	rangeMin	rangeMax	points
# 0	main	Ag	Johnson	main\Ag\Johnson.yml	1	1	0.1879	1.937	49
# 33	main	Ar	Sinnock-liquid-83.81K	main\Ar\Sinnock-liquid-83.81K.yml	1	0	0.3612	0.6439	9
# 34	main	Ar	Sinnock-solid-83.81K	main\Ar\Sinnock-solid-83.81K.yml	1	0	0.3612	0.6439	9
# 35	main	Ar	Sinnock-solid-80K	main\Ar\Sinnock-solid-80K.yml	1	0	0.3612	0.6439	9
# 36	main	Ar	Sinnock-solid-70K	main\Ar\Sinnock-solid-70K.yml	1	0	0.3612	0.6439	9
# 37	main	Ar	Sinnock-solid-60K	main\Ar\Sinnock-solid-60K.yml	1	0	0.3612	0.6439	9
# 38	main	Ar	Sinnock-solid-50K	main\Ar\Sinnock-solid-50K.yml	1	0	0.3612	0.6439	9
# 39	main	Ar	Sinnock-solid-40K	main\Ar\Sinnock-solid-40K.yml	1	0	0.3612	0.6439	9
# 40	main	Ar	Sinnock-solid-30K	main\Ar\Sinnock-solid-30K.yml	1	0	0.3612	0.6439	9
# 41	main	Ar	Sinnock-solid-20K	main\Ar\Sinnock-solid-20K.yml	1	0	0.3612	0.6439	9
# 42	main	AlAs	Fern	main\AlAs\Fern.yml	1	0	0.56	2.2	100
# 43	main	AlAs	Rakic	main\AlAs\Rakic.yml	1	1	0.2214	2.4797	200
# 44	main	GaAs	Aspnes	main\GaAs\Aspnes.yml	1	1	0.2066	0.8266	46
# 45	main	GaAs	Skauli	main\GaAs\Skauli.yml	1	0	0.97	17.0	100
# 46	main	GaAs	Jellison	main\GaAs\Jellison.yml	1	1	0.234	0.84	187
# 47	main	GaAs	Kachare	main\GaAs\Kachare.yml	1	0	1.4	11.0	100
# 48	main	GaAs	Adachi	main\GaAs\Adachi.yml	1	1	0.20664	12.398	200
# 49	main	GaAs	Rakic	main\GaAs\Rakic.yml	1	1	0.20664	12.398	200
# 50	main	GaAs	Ozaki	main\GaAs\Ozaki.yml	1	1	0.2214	1.0332	500
# 51	main	InAs	Aspnes	main\InAs\Aspnes.yml	1	1	0.2066	0.8266	46
# 52	main	InAs	Lorimor	main\InAs\Lorimor.yml	1	0	3.7	31.3	100
# 53	main	InAs	Adachi	main\InAs\Adachi.yml	1	1	0.20664	12.398	200
# 54	main	CdGeAs2	Boyd-o	main\CdGeAs2\Boyd-o.yml	1	0	2.4	11.5	100
# 55	main	CdGeAs2	Boyd-e	main\CdGeAs2\Boyd-e.yml	1	0	2.4	11.5	100
# 56	main	ZnSiAs2	Boyd-o	main\ZnSiAs2\Boyd-o.yml	1	0	0.7	11.5	100
# 57	main	ZnSiAs2	Boyd-e	main\ZnSiAs2\Boyd-e.yml	1	0	0.7	11.5	100
# 58	main	Au	Johnson	main\Au\Johnson.yml	1	1	0.1879	1.937	49
# 59	main	Au	McPeak	main\Au\McPeak.yml	1	1	0.3	1.7	141
# 60	main	Au	Babar	main\Au\Babar.yml	1	1	0.2066	12.4	69
# 61	main	Au	Olmon-ev	main\Au\Olmon-ev.yml	1	1	0.3	24.93	448
# 62	main	Au	Olmon-sc	main\Au\Olmon-sc.yml	1	1	0.3	24.93	448
# 63	main	Au	Olmon-ts	main\Au\Olmon-ts.yml	1	1	0.3	24.93	448
# 96	main	LuAl3(BO3)4	Fang-o	main\LuAl3(BO3)4\Fang-o.yml	1	0	0.266	1.338	100
# 97	main	LuAl3(BO3)4	Fang-e	main\LuAl3(BO3)4\Fang-e.yml	1	0	0.266	1.338	100
# 98	main	Be	Rakic-BB	main\Be\Rakic-BB.yml	1	1	0.24797	61.992	200
# 99	main	Be	Rakic-LD	main\Be\Rakic-LD.yml	1	1	0.24797	61.992	1000
# 100	main	Bi	Hagemann	main\Bi\Hagemann.yml	1	1	2.48e-06	6.199	150
# 101	main	Bi	Werner	main\Bi\Werner.yml	1	1	0.017586	2.479684	150
# 102	main	Bi	Werner-DFT	main\Bi\Werner-DFT.yml	1	1	0.017586	2.479684	150
# 103	main	AgBr	SchrÃ¶ter	main\AgBr\Schroter.yml	1	0	0.495	0.67	100
# 104	main	CsBr	Li	main\CsBr\Li.yml	1	0	0.21	55.0	100
# 105	main	CsBr	Querry	main\CsBr\Querry.yml	1	1	0.213	149.2537	312
# 106	main	CsBr	Rodney	main\CsBr\Rodney.yml	1	0	0.365	39.0	100
# 107	main	KBr	Li	main\KBr\Li.yml	1	0	0.2	42.0	100
# 108	main	LiBr	Li	main\LiBr\Li.yml	1	0	0.21	20.0	100
# 109	main	NaBr	Li	main\NaBr\Li.yml	1	0	0.21	34.0	100
# 110	main	RbBr	Li	main\RbBr\Li.yml	1	0	0.21	50.0	100
# 111	main	TlBr	Palik	main\TlBr\Palik.yml	1	0	0.57	39.4	100
# 112	main	TlBr	Schroter	main\TlBr\Schroter.yml	1	0	0.54	0.65	100
# 113	main	C	Phillip	main\C\Phillip.yml	1	1	0.035424054	10.0	176
# 114	main	C	Peter	main\C\Peter.yml	1	0	0.226	0.76	100
# 115	main	C	Dore	main\C\Dore.yml	1	1	2.5	500.0	241
# 116	main	C	Hagemann	main\C\Hagemann.yml	1	1	4.133e-05	124.0	100
# 117	main	C	Larruquert	main\C\Larruquert.yml	1	1	0.019656426	10.07918931	364
# 118	main	C	Arakawa	main\C\Arakawa.yml	1	1	0.3263	2.0664	18
# 119	main	C	Djurisic-o	main\C\Djurisic-o.yml	1	1	0.030996	10.332	1000
# 120	main	C	Djurisic-e	main\C\Djurisic-e.yml	1	1	0.030996	0.5904	1000
# 121	main	C	Querry-DixonKS2	main\C\Querry-DixonKS2.yml	1	1	0.21	55.5556	612
# 122	main	C	Querry-DixonHPN2	main\C\Querry-DixonHPN2.yml	1	1	0.2	55.5556	613
# 123	main	C	Querry-Dixon200-10	main\C\Querry-Dixon200-10.yml	1	1	0.21	55.5556	612
# 124	main	C	Querry-AsburyMicro260	main\C\Querry-AsburyMicro260.yml	1	1	0.21	55.5556	612
# 125	main	C	Querry-Dixon1102	main\C\Querry-Dixon1102.yml	1	1	0.2	55.5556	613
# 126	main	C	Querry-Asbury3222	main\C\Querry-Asbury3222.yml	1	1	0.2	55.5556	613
# 127	main	C	Querry-Pyrolytic	main\C\Querry-Pyrolytic.yml	1	1	0.21	55.5556	612
# 128	main	C	Weber	main\C\Weber.yml	1	1	0.210873	0.999007	499
# 129	main	B4C	Larruquert	main\B4C\Larruquert.yml	1	1	0.001737709	21.53810759	1480
# 130	main	SiC	Singh-o	main\SiC\Singh-o.yml	1	0	0.488	1.064	100
# 131	main	SiC	Singh-e	main\SiC\Singh-e.yml	1	0	0.488	1.064	100
# 132	main	SiC	Wang-6H-o	main\SiC\Wang-6H-o.yml	1	0	0.4358	2.325	100
# 133	main	SiC	Wang-6H-e	main\SiC\Wang-6H-e.yml	1	0	0.4358	2.325	100
# 134	main	SiC	Wang-4H-o	main\SiC\Wang-4H-o.yml	1	0	0.4047	5.0	100
# 135	main	SiC	Wang-4H-e	main\SiC\Wang-4H-e.yml	1	0	0.4047	2.325	100
# 136	main	SiC	Fischer-o	main\SiC\Fischer-o.yml	1	0	17.0	150.0	100
# 137	main	SiC	Fischer-e	main\SiC\Fischer-e.yml	1	0	17.0	150.0	100
# 138	main	SiC	Shaffer	main\SiC\Shaffer.yml	1	0	0.467	0.691	100
# 139	main	SiC	Larruquert	main\SiC\Larruquert.yml	1	1	0.00615447	131.7250957	508
# 140	main	TiC	Pfluger	main\TiC\Pfluger.yml	1	1	0.03107	2.4797	52
# 141	main	VC	Pfluger	main\VC\Pfluger.yml	1	1	0.03107	2.4797	52
# 142	main	CaCO3	Ghosh-o	main\CaCO3\Ghosh-o.yml	1	0	0.204	2.172	100
# 143	main	CaCO3	Ghosh-e	main\CaCO3\Ghosh-e.yml	1	0	0.204	2.172	100
# 144	main	CaMg(CO3)2	Querry-o	main\CaMg(CO3)2\Querry-o.yml	1	1	2.5	40.0	376
# 145	main	CaMg(CO3)2	Querry-e	main\CaMg(CO3)2\Querry-e.yml	1	1	2.5	50.0	381
# 146	main	Ca	Mathewson	main\Ca\Mathewson.yml	1	1	0.33968	1.65312	59
# 147	main	Ca	Rodriguez-de_Marcos	main\Ca\Rodriguez-de Marcos.yml	1	1	0.001233674	0.316348631	1848
# 148	main	Ce	Fernandez-Perea	main\Ce\Fernandez-Perea.yml	1	1	0.00103238	0.206638625	1265
# 149	main	AgCl	Tilton	main\AgCl\Tilton.yml	1	0	0.578	20.6	100
# 150	main	CsCl	Li	main\CsCl\Li.yml	1	0	0.18	40.0	100
# 151	main	CuCl	Feldman	main\CuCl\Feldman.yml	1	0	0.43	2.5	100
# 152	main	KCl	Li	main\KCl\Li.yml	1	0	0.18	35.0	100
# 153	main	KCl	Querry	main\KCl\Querry.yml	1	1	0.22	166.6667	312
# 154	main	LiCl	Li	main\LiCl\Li.yml	1	0	0.17	16.0	100
# 155	main	NaCl	Li	main\NaCl\Li.yml	1	0	0.2	30.0	100
# 156	main	NaCl	Querry	main\NaCl\Querry.yml	1	1	0.22	166.6667	312
# 157	main	RbCl	Li	main\RbCl\Li.yml	1	0	0.18	40.0	100
# 158	main	TlCl	Schroter	main\TlCl\Schroter.yml	1	0	0.43	0.66	100
# 159	main	Co	Johnson	main\Co\Johnson.yml	1	1	0.188	1.937	49
# 160	main	Co	Werner	main\Co\Werner.yml	1	1	0.017586	2.479684	150
# 161	main	Co	Werner-DFT	main\Co\Werner-DFT.yml	1	1	0.017586	2.479684	150
#
# 294	main	Mg	Vidal-Dasilva	main\Mg\Vidal-Dasilva.yml	1	1	0.000953725	0.049593675	1706
# 295	main	Mn	Johnson	main\Mn\Johnson.yml	1	1	0.188	1.937	49
# 296	main	Mn	Querry	main\Mn\Querry.yml	1	1	0.22	55.5556	306
# 297	main	Mo	Ordal	main\Mo\Ordal.yml	1	1	0.667	154.0	50
# 298	main	Mo	Werner	main\Mo\Werner.yml	1	1	0.017586	2.479684	150
# 299	main	Mo	Windt	main\Mo\Windt.yml	1	1	0.00236	0.12157	36
# 300	main	Mo	Querry	main\Mo\Querry.yml	1	1	0.2063	166.6667	314
# 301	main	Mo	Kirillova	main\Mo\Kirillova.yml	1	1	0.265	20.0	98
# 302	main	Mo	Werner-DFT	main\Mo\Werner-DFT.yml	1	1	0.017586	2.479684	150
# 303	main	CaMoO4	Bond-o	main\CaMoO4\Bond-o.yml	1	0	0.45	3.8	100
# 304	main	CaMoO4	Bond-e	main\CaMoO4\Bond-e.yml	1	0	0.45	3.8	100
# 305	main	PbMoO4	Malitson-o	main\PbMoO4\Malitson-o.yml	1	0	0.44	1.08	100
# 306	main	PbMoO4	Malitson-e	main\PbMoO4\Malitson-e.yml	1	0	0.44	1.08	100
# 307	main	SrMoO4	Bond-o	main\SrMoO4\Bond-o.yml	1	0	0.45	2.4	100
# 308	main	SrMoO4	Bond-e	main\SrMoO4\Bond-e.yml	1	0	0.45	2.4	100
# 309	main	N2	Peck-0C	main\N2\Peck-0C.yml	1	0	0.4679	2.0587	100
# 310	main	N2	Peck-15C	main\N2\Peck-15C.yml	1	0	0.4679	2.0587	100
# 311	main	N2	Griesmann	main\N2\Griesmann.yml	1	0	0.145	0.27	100
# 312	main	AlN	Kischkat	main\AlN\Kischkat.yml	1	1	1.53846	14.28571	1451
# 313	main	AlN	Pastrnak-o	main\AlN\Pastrnak-o.yml	1	0	0.22	5.0	100
# 314	main	AlN	Pastrnak-e	main\AlN\Pastrnak-e.yml	1	0	0.22	5.0	100
# 315	main	GaN	Barker-o	main\GaN\Barker-o.yml	1	0	0.35	10.0	100
# 316	main	GaN	Barker-e	main\GaN\Barker-e.yml	1	0	0.35	10.0	100
# 317	main	GaN	Lin-wurtzite	main\GaN\Lin-wurtzite.yml	1	0	0.368124	0.991745	53
# 318	main	GaN	Lin-zincblende	main\GaN\Lin-zincblende.yml	1	0	0.385447	0.960283	32
# 319	main	GaN	Kawashima	main\GaN\Kawashima.yml	1	1	0.13051	0.99187	500
# 320	main	NH3	Cuthbertson	main\NH3\Cuthbertson.yml	1	0	0.47999	0.670785	100
# 321	main	Si3N4	Luke	main\Si3N4\Luke.yml	1	0	0.31	5.504	100
# 322	main	Si3N4	Kischkat	main\Si3N4\Kischkat.yml	1	1	1.53846	14.28571	1451
# 323	main	Si3N4	Philipp	main\Si3N4\Philipp.yml	1	0	0.207	1.24	100
# 324	main	TiN	Pfluger	main\TiN\Pfluger.yml	1	1	0.03107	2.4797	50
# 325	main	TiN	Schnabel	main\TiN\Schnabel.yml	1	1	0.2916	0.8091	327
# 326	main	VN	Pfluger	main\VN\Pfluger.yml	1	1	0.03107	2.4797	52
# 327	main	Na	Smith	main\Na\Smith.yml	1	1	0.312539	2.237982	23
# 328	main	Na	Inagaki	main\Na\Inagaki.yml	1	1	0.326	2.066	33
# 329	main	Na	Monin	main\Na\Monin.yml	1	1	0.2536	0.62	13
# 330	main	Na	Yamaguchi	main\Na\Yamaguchi.yml	1	1	0.2	0.6	29
# 331	main	Na	Althoff	main\Na\Althoff.yml	1	1	2.25	10.15	8
# 332	main	Na	Ives	main\Na\Ives.yml	1	1	0.2536	0.578	8
# 333	main	Na	Inagaki-liquid	main\Na\Inagaki-liquid.yml	1	1	0.335	2.0	23
# 334	main	Nb	Windt	main\Nb\Windt.yml	1	1	0.00236	0.12157	36
# 335	main	Nb	Golovashkin-293K	main\Nb\Golovashkin-293K.yml	1	1	0.4	10.0	65
# 336	main	Nb	Golovashkin-78K	main\Nb\Golovashkin-78K.yml	1	1	0.4	9.2	61
# 337	main	Nb	Golovashkin-4.2K	main\Nb\Golovashkin-4.2K.yml	1	1	0.4	9.2	78
# 338	main	KNbO3	Umemura-Î±	main\KNbO3\Umemura-alpha.yml	1	0	0.4	5.3	100
# 339	main	KNbO3	Umemura-Î²	main\KNbO3\Umemura-beta.yml	1	0	0.4	5.3	100
# 340	main	KNbO3	Umemura-Î³	main\KNbO3\Umemura-gamma.yml	1	0	0.4	5.3	100
# 341	main	LiNbO3	Zelmon-o	main\LiNbO3\Zelmon-o.yml	1	0	0.4	5.0	100
# 342	main	LiNbO3	Zelmon-e	main\LiNbO3\Zelmon-e.yml	1	0	0.4	5.0	100
# 343	main	Ne	Bideau-Mehu	main\Ne\Bideau-Mehu.yml	1	0	0.1404	0.5462	100
# 344	main	Ne	Cuthbertson	main\Ne\Cuthbertson.yml	1	0	0.2894	0.5462	100
# 345	main	Ni	Johnson	main\Ni\Johnson.yml	1	1	0.188	1.937	49
# 346	main	Ni	Werner	main\Ni\Werner.yml	1	1	0.017586	2.479684	150
# 347	main	Ni	Ordal	main\Ni\Ordal.yml	1	1	0.667	286.0	52
# 348	main	Ni	Rakic-BB	main\Ni\Rakic-BB.yml	1	1	0.24797	6.1992	200
# 349	main	Ni	Rakic-LD	main\Ni\Rakic-LD.yml	1	1	0.24797	6.1992	1000
# 350	main	Ni	Werner-DFT	main\Ni\Werner-DFT.yml	1	1	0.017586	2.479684	150
# 351	main	O2	Smith	main\O2\Smith.yml	1	0	0.1843	0.28824	22
# 352	main	O2	Zhang	main\O2\Zhang.yml	1	0	0.4	1.8	100
# 353	main	Al2O3	Malitson-o	main\Al2O3\Malitson-o.yml	1	0	0.2	5.0	100
# 354	main	Al2O3	Malitson-e	main\Al2O3\Malitson-e.yml	1	0	0.2	5.0	100
# 355	main	Al2O3	Querry-o	main\Al2O3\Querry-o.yml	1	1	0.21	55.5556	612
# 356	main	Al2O3	Querry-e	main\Al2O3\Querry-e.yml	1	1	0.21	55.5556	612
# 357	main	Al2O3	Malitson	main\Al2O3\Malitson.yml	1	0	0.2652	5.577	100
# 358	main	Al2O3	Hagemann	main\Al2O3\Hagemann.yml	1	1	0.0007749	0.2066	100
# 360	main	Al2O3	Kischkat	main\Al2O3\Kischkat.yml	1	1	1.53941	14.28571	1450
# 361	main	Al2O3	Querry	main\Al2O3\Querry.yml	1	1	0.21	12.5	550
# 362	main	BeO	Edwards-o	main\BeO\Edwards-o.yml	1	0	0.44	7.0	100
# 363	main	BeO	Edwards-e	main\BeO\Edwards-e.yml	1	0	0.44	7.0	100
# 364	main	CO	Smith	main\CO1\Smith.yml	1	0	0.1672	0.2894	38
# 365	main	CO2	Bideau-Mehu	main\CO2\Bideau-Mehu.yml	1	0	0.1807	1.6945	100
# 366	main	CO2	Old	main\CO2\Old.yml	1	0	0.480126	1.817228	100
# 367	main	CuO	Brimhall	main\CuO\Brimhall.yml	1	1	0.0101	0.0348	32
# 368	main	Cu2O	Querry	main\Cu2O\Querry.yml	1	1	2.5	55.5556	383
# 369	main	Dy2O3	Medenbach	main\Dy2O3\Medenbach.yml	1	0	0.435	0.644	100
# 370	main	Fe2O3	Querry-o	main\Fe2O3\Querry-o.yml	1	1	0.21	90.9091	619
# 371	main	Fe2O3	Querry-e	main\Fe2O3\Querry-e.yml	1	1	0.21	55.5556	613
# 372	main	Fe3O4	Querry	main\Fe3O4\Querry.yml	1	1	0.21	55.5556	612
# 373	main	GeO2	Fleming	main\GeO2\Fleming.yml	1	0	0.36	4.3	100
# 374	main	H2O	Hale	main\H2O\Hale.yml	1	1	0.2	200.0	169
# 375	main	H2O	Wang	main\H2O\Wang.yml	0	1	1.2	1.9	351
# 376	main	H2O	Kedenburg	main\H2O\Kedenburg.yml	1	1	0.5	1.6	1132
# 377	main	H2O	Daimon-19.0C	main\H2O\Daimon-19.0C.yml	1	0	0.182	1.129	100
# 378	main	H2O	Daimon-20.0C	main\H2O\Daimon-20.0C.yml	1	0	0.182	1.129	100
# 379	main	H2O	Daimon-21.5C	main\H2O\Daimon-21.5C.yml	1	0	0.182	1.129	100
# 380	main	H2O	Daimon-24.0C	main\H2O\Daimon-24.0C.yml	1	0	0.182	1.129	100
# 381	main	H2O	Segelstein	main\H2O\Segelstein.yml	1	1	0.033962528	10000000.0	1247
# 382	main	H2O	Asfar-H2O	main\H2O\Asfar.yml	1	1	22.22	1733.0	34
# 383	main	H2O	Warren-2008	main\H2O\Warren-2008.yml	1	1	0.0443	2000000.0	486
# 384	main	H2O	Warren-1984	main\H2O\Warren-1984.yml	1	1	0.0443	167.0	468
# 385	main	H2O	Kedenburg-D2O	main\D2O\Kedenburg.yml	1	1	0.5	1.6	1001
# 386	main	H2O	Wang-D2O	main\D2O\Wang.yml	0	1	1.2	2.6	701
# 387	main	H2O	Asfar-D2O	main\D2O\Asfar.yml	1	1	250.0	2000.0	8
# 388	main	HfO2	Wood	mixed crystals\HfO2-Y2O3\Wood.yml	1	0	0.365	5.0	100
# 389	main	Lu2O3	Medenbach	main\Lu2O3\Medenbach.yml	1	0	0.435	0.644	100
# 390	main	MgO	Stephens	main\MgO\Stephens.yml	1	0	0.36	5.4	100
# 391	main	MgO	Stephens-vis	main\MgO\Stephens-vis.yml	1	0	0.4047	0.7679	100
# 422	main	TiO2	Bodurov	main\TiO2\Bodurov.yml	1	0	0.405	0.635	100
# 423	main	Y2O3	Nigara	main\Y2O3\Nigara.yml	1	0	0.25	9.6	100
# 424	main	Yb2O3	Medenbach	main\Yb2O3\Medenbach.yml	1	0	0.435	0.644	100
# 425	main	ZnO	Bond-o	main\ZnO\Bond-o.yml	1	0	0.45	4.0	100
# 426	main	ZnO	Bond-e	main\ZnO\Bond-e.yml	1	0	0.45	4.0	100
# 427	main	ZnO	Stelling	main\ZnO\Stelling.yml	1	1	0.30158	1.68492	640
# 428	main	ZnO	Querry	main\ZnO\Querry.yml	1	1	0.21	55.5556	612
# 429	main	ZnO	Bodurov	main\ZnO\Bodurov.yml	1	0	0.405	0.635	100
# 430	main	ZrO2	Wood	mixed crystals\ZrO2-Y2O3\Wood.yml	1	0	0.361	5.135	100
# 431	main	ZrO2	Bodurov	main\ZrO2\Bodurov.yml	1	0	0.405	0.635	100
# 432	main	Os	Windt	main\Os\Windt.yml	1	1	0.00236	0.12157	36
# 433	main	Os	Nemoshkalenko-o	main\Os\Nemoshkalenko-o.yml	1	1	0.24	15.0	92
# 434	main	Os	Nemoshkalenko-e	main\Os\Nemoshkalenko-e.yml	1	1	0.25	8.0	92
# 435	main	BP	Wettling	main\BP\Wettling.yml	1	0	0.4545	0.6328	6
# 436	main	CdGeP2	Boyd-20-o	main\CdGeP2\Boyd-20-o.yml	1	0	0.8	12.5	100
# 437	main	CdGeP2	Boyd-20-e	main\CdGeP2\Boyd-20-e.yml	1	0	0.8	12.5	100
# 438	main	CdGeP2	Boyd-118-o	main\CdGeP2\Boyd-118-o.yml	1	0	0.8	12.5	100
# 439	main	CdGeP2	Boyd-118-e	main\CdGeP2\Boyd-118-e.yml	1	0	0.8	12.5	100
# 440	main	GaP	Aspnes	main\GaP\Aspnes.yml	1	1	0.2066	0.8266	46
# 441	main	GaP	Jellison	main\GaP\Jellison.yml	1	1	0.234	0.84	187
# 442	main	GaP	Parsons	main\GaP\Parsons.yml	1	0	54.369	366.03	17
# 443	main	GaP	Bond	main\GaP\Bond.yml	1	0	0.5	4.0	22
# 444	main	GaP	Adachi	main\GaP\Adachi.yml	1	1	0.20664	12.398	200
# 445	main	InP	Aspnes	main\InP\Aspnes.yml	1	1	0.2066	0.8266	46
# 446	main	InP	Pettit	main\InP\Pettit.yml	1	0	0.95	10.0	100
# 447	main	InP	Adachi	main\InP\Adachi.yml	1	1	0.20664	12.398	200
# 448	main	ZnGeP2	Das-o	main\ZnGeP2\Das-o.yml	1	0	1.32	11.0	100
# 449	main	ZnGeP2	Das-e	main\ZnGeP2\Das-e.yml	1	0	1.32	11.0	100
# 450	main	ZnGeP2	Zelmon-o	main\ZnGeP2\Zelmon-o.yml	1	0	2.0	9.0	100
# 451	main	ZnGeP2	Zelmon-e	main\ZnGeP2\Zelmon-e.yml	1	0	2.0	9.0	100
# 452	main	ZnGeP2	Boyd-20-o	main\ZnGeP2\Boyd-20-o.yml	1	0	0.64	12.0	100
# 453	main	ZnGeP2	Boyd-20-e	main\ZnGeP2\Boyd-20-e.yml	1	0	0.64	12.0	100
# 516	main	CuGaS2	Boyd-120-o	main\CuGaS2\Boyd-120-o.yml	1	0	0.55	11.5	100
# 517	main	CuGaS2	Boyd-120-e	main\CuGaS2\Boyd-120-e.yml	1	0	0.55	11.5	100
# 518	main	GaS	Kato-o	main\GaS\Kato-o.yml	1	0	0.633	10.591	100
# 519	main	GaS	Kato-e	main\GaS\Kato-e.yml	1	0	0.633	10.591	100
# 520	main	HgS	Bond-o	main\HgS\Bond-o.yml	1	0	0.62	11.0	100
# 521	main	HgS	Bond-e	main\HgS\Bond-e.yml	1	0	0.62	11.0	100
# 522	main	MoS2	Beal	main\MoS2\Beal.yml	1	1	0.0811	1.236	100
# 523	main	MoS2	Yim-2nm	main\MoS2\Yim-2nm.yml	1	1	0.382448	0.886647	22
# 524	main	MoS2	Yim-3nm	main\MoS2\Yim-3nm.yml	1	1	0.382417	0.888102	18
# 525	main	MoS2	Yim-20nm	main\MoS2\Yim-20nm.yml	1	1	0.381514	0.884671	17
# 526	main	MoS2	Zhang	main\MoS2\Zhang.yml	1	1	0.4	0.75	351
# 527	main	MoS2	Jung	main\MoS2\Jung.yml	1	1	0.3813	0.89341	188
# 528	main	PbS	Zemel	main\PbS\Zemel.yml	1	0	3.5	10.0	100
# 529	main	WS2	Jung	main\WS2\Jung.yml	1	1	0.38135	0.89352	188
# 530	main	ZnS	Debenham	main\ZnS\Debenham.yml	1	0	0.405	13.0	100
# 531	main	ZnS	Querry	main\ZnS\Querry.yml	1	1	0.22	166.6667	312
# 532	main	ZnS	Ozaki	main\ZnS\Ozaki.yml	1	1	0.2214	1.0332	500
# 533	main	CaSO4	Querry-Î±	main\CaSO4\Querry-alpha.yml	1	1	2.5	55.5556	383
# 534	main	CaSO4	Querry-Î²	main\CaSO4\Querry-beta.yml	1	1	2.5	55.5556	383
# 535	main	CaSO4	Querry-Î³	main\CaSO4\Querry-gamma.yml	1	1	2.5	55.5556	383
# 536	main	AlSb	Zollner	main\AlSb\Zollner.yml	1	1	0.2138	0.8856	45
# 537	main	AlSb	Adachi	main\AlSb\Adachi.yml	1	1	0.20664	12.398	500
# 538	main	AlSb	Djurisic	main\AlSb\Djurisic.yml	1	1	0.20664	12.398	500
# 539	main	GaSb	Aspnes	main\GaSb\Aspnes.yml	1	1	0.2066	0.8266	46
# 540	main	GaSb	Ferrini	semiconductor alloys\AlSb-GaSb\Ferrini-0.yml	1	1	0.207	2.48	56
# 541	main	GaSb	Adachi	main\GaSb\Adachi.yml	1	1	0.20664	12.398	200
# 542	main	GaSb	Djurisic	main\GaSb\Djurisic.yml	1	1	0.20664	2.4797	500
# 543	main	InSb	Aspnes	main\InSb\Aspnes.yml	1	1	0.2066	0.8266	46
# 544	main	InSb	Adachi	main\InSb\Adachi.yml	1	1	0.20664	12.398	200
# 545	main	InSb	Djurisic	main\InSb\Djurisic.yml	1	1	0.20664	1.2398	500
# 546	main	Sc	Larruquert	main\Sc\Larruquert.yml	1	1	0.001239842	0.189781921	373
# 547	main	Se	Campel-o	main\Se\Campel-o.yml	1	0	1.06	10.6	4
# 548	main	Se	Campel-e	main\Se\Campel-e.yml	1	0	1.06	10.6	4
# 549	main	Se	Ciesielski	main\Se\Ciesielski.yml	1	1	0.2	2.0	278
# 550	main	CdSe	Lisitsa-o	main\CdSe\Lisitsa-o.yml	1	0	1.01	22.0	100
# 551	main	CdSe	Lisitsa-e	main\CdSe\Lisitsa-e.yml	1	0	1.01	22.0	100
# 552	main	CdSe	Ninomiya-o	main\CdSe\Ninomiya-o.yml	1	1	0.23393	1.0332	500
# 553	main	CdSe	Ninomiya-e	main\CdSe\Ninomiya-e.yml	1	1	0.23393	1.0332	500
# 554	main	CdSe	Ninomiya-cubic	main\CdSe\Ninomiya-cubic.yml	1	1	0.20664	0.82656	500
# 555	main	GaSe	Kato-o	main\GaSe\Kato-o.yml	1	0	0.8	1620.0	100
# 556	main	GaSe	Kato-e	main\GaSe\Kato-e.yml	1	0	0.8	1620.0	100
# 557	main	MoSe2	Beal	main\MoSe2\Beal.yml	1	1	0.04387	1.161	100
# 558	main	PbSe	Zemel	main\PbSe\Zemel.yml	1	0	5.0	10.0	100
# 559	main	PbSe	Suzuki	main\PbSe\Suzuki.yml	1	1	0.2296	1.0781	500
# 560	main	WSe2	Jung	main\WSe2\Jung.yml	1	1	0.38135	0.89352	188
# 561	main	ZnSe	Marple	main\ZnSe\Marple.yml	1	0	0.48	2.5	100
# 562	main	ZnSe	Querry	main\ZnSe\Querry.yml	1	1	0.5	21.7391	278
# 563	main	ZnSe	Connolly	main\ZnSe\Connolly.yml	1	0	0.54	18.2	100
# 564	main	ZnSe	Adachi	main\ZnSe\Adachi.yml	1	1	0.23393	0.82656	500
# 565	main	AgGaSe2	Harasaki-o	main\AgGaSe2\Harasaki-o.yml	1	0	0.81	16.0	100
# 566	main	AgGaSe2	Harasaki-e	main\AgGaSe2\Harasaki-e.yml	1	0	0.81	16.0	100
# 567	main	AgGaSe2	Boyd-o	main\AgGaSe2\Boyd-o.yml	1	0	0.725	13.5	100
# 568	main	AgGaSe2	Boyd-e	main\AgGaSe2\Boyd-e.yml	1	0	0.725	13.5	100
# 569	main	Tl3AsSe3	Ewbank-o	main\Tl3AsSe3\Ewbank-o.yml	1	0	2.0	12.0	100
# 570	main	Tl3AsSe3	Ewbank-e	main\Tl3AsSe3\Ewbank-e.yml	1	0	2.0	12.0	100
# 571	main	Si	Aspnes	main\Si\Aspnes.yml	1	1	0.2066	0.8266	46
# 572	main	Si	Schinke	main\Si\Schinke.yml	1	1	0.25	1.45	121
# 573	main	Si	Green-2008	main\Si\Green-2008.yml	1	1	0.25	1.45	121
# 574	main	Si	Chandler-Horowitz	main\Si\Chandler-Horowitz.yml	1	1	2.5	22.222	586
# 580	main	Si	Green-1995	main\Si\Green-1995.yml	1	1	0.25	1.45	76
# 581	main	Si	Daub	main\Si\Daub.yml	0	1	0.941	1.421	71
# 582	main	Si	Vuye-20C	main\Si\Vuye-20C.yml	1	1	0.2638	0.8266	129
# 583	main	Si	Vuye-100C	main\Si\Vuye-100C.yml	1	1	0.2638	0.8266	129
# 584	main	Si	Vuye-150C	main\Si\Vuye-150C.yml	1	1	0.2638	0.8266	129
# 585	main	Si	Vuye-200C	main\Si\Vuye-200C.yml	1	1	0.2638	0.8266	129
# 586	main	Si	Vuye-250C	main\Si\Vuye-250C.yml	1	1	0.2638	0.8266	129
# 587	main	Si	Vuye-300C	main\Si\Vuye-300C.yml	1	1	0.2638	0.8266	129
# 588	main	Si	Vuye-350C	main\Si\Vuye-350C.yml	1	1	0.2638	0.8266	129
# 589	main	Si	Vuye-400C	main\Si\Vuye-400C.yml	1	1	0.2638	0.8266	129
# 590	main	Si	Vuye-450C	main\Si\Vuye-450C.yml	1	1	0.2638	0.8266	129
# 591	main	Si	Jellison	main\Si\Jellison.yml	1	1	0.234	0.84	186
# 592	main	Si	Edwards	main\Si\Edwards.yml	1	0	2.4373	25.0	100
# 593	main	Si	Li-100K	main\Si\Li-100K.yml	1	0	1.2	14.0	35
# 594	main	Si	Li-150K	main\Si\Li-150K.yml	1	0	1.2	14.0	35
# 595	main	Si	Li-200K	main\Si\Li-200K.yml	1	0	1.2	14.0	35
# 596	main	Si	Li-250K	main\Si\Li-250K.yml	1	0	1.2	14.0	35
# 597	main	Si	Li-293K	main\Si\Li-293K.yml	1	0	1.2	14.0	35
# 598	main	Si	Li-350K	main\Si\Li-350K.yml	1	0	1.2	14.0	35
# 599	main	Si	Li-400K	main\Si\Li-400K.yml	1	0	1.2	14.0	35
# 600	main	Si	Li-450K	main\Si\Li-450K.yml	1	0	1.2	14.0	35
# 601	main	Si	Li-500K	main\Si\Li-500K.yml	1	0	1.2	14.0	35
# 602	main	Si	Li-550K	main\Si\Li-550K.yml	1	0	1.2	14.0	35
# 603	main	Si	Li-600K	main\Si\Li-600K.yml	1	0	1.2	14.0	35
# 604	main	Si	Li-650K	main\Si\Li-650K.yml	1	0	1.2	14.0	35
# 605	main	Si	Li-700K	main\Si\Li-700K.yml	1	0	1.2	14.0	35
# 606	main	Si	Li-750K	main\Si\Li-750K.yml	1	0	1.2	14.0	35
# 607	main	Si	Salzberg	main\Si\Salzberg.yml	1	0	1.357	11.04	100
# 608	main	Si	Pierce	main\Si\Pierce.yml	1	1	0.1033	2.066	46
# 609	main	Bi12SiO20	Gospodinov	main\Bi12SiO20\Gospodinov.yml	1	0	0.48	0.7	100
# 610	main	Sn	Golovashkin-293K	main\Sn\Golovashkin-293K.yml	1	1	0.73	12.0	23
# 611	main	Sn	Golovashkin-78K	main\Sn\Golovashkin-78K.yml	1	1	0.73	12.0	23
# 612	main	Sn	Golovashkin-4.2K	main\Sn\Golovashkin-4.2K.yml	1	1	0.93	12.0	19
# 613	main	Sr	Rodriguez-de_Marcos	main\Sr\Rodriguez-de Marcos.yml	1	1	0.001011751	0.212037407	1124
# 614	main	Ta	Ordal	main\Ta\Ordal.yml	1	1	0.667	125.0	49
# 615	main	Ta	Werner	main\Ta\Werner.yml	1	1	0.017586	2.479684	150
# 616	main	Ta	Windt	main\Ta\Windt.yml	1	1	0.00236	0.12157	36
# 617	main	Ta	Werner-DFT	main\Ta\Werner-DFT.yml	1	1	0.017586	2.479684	150
#
# 2544	other	V-Ga	Golovashkin-293K	alloys\V-Ga\Golovashkin-293K.yml	1	1	0.45	10.0	31
# 2545	other	V-Ga	Golovashkin-78K	alloys\V-Ga\Golovashkin-78K.yml	1	1	0.45	2.6	32
# 2546	other	AlAs-GaAs	Aspnes-0	semiconductor alloys\AlAs-GaAs\Aspnes-0.yml	1	1	0.2066	0.8266	46
# 2547	other	AlAs-GaAs	Aspnes-9.9	semiconductor alloys\AlAs-GaAs\Aspnes-9.9.yml	1	1	0.2066	0.8266	46
# 2548	other	AlAs-GaAs	Aspnes-19.8	semiconductor alloys\AlAs-GaAs\Aspnes-19.8.yml	1	1	0.2066	0.8266	46
# 2549	other	AlAs-GaAs	Aspnes-31.5	semiconductor alloys\AlAs-GaAs\Aspnes-31.5.yml	1	1	0.2066	0.8266	46
# 2550	other	AlAs-GaAs	Aspnes-41.9	semiconductor alloys\AlAs-GaAs\Aspnes-41.9.yml	1	1	0.2066	0.8266	46
# 2551	other	AlAs-GaAs	Aspnes-49.1	semiconductor alloys\AlAs-GaAs\Aspnes-49.1.yml	1	1	0.2066	0.8266	46
# 2552	other	AlAs-GaAs	Aspnes-59.0	semiconductor alloys\AlAs-GaAs\Aspnes-59.0.yml	1	1	0.2066	0.8266	46
# 2553	other	AlAs-GaAs	Aspnes-70.0	semiconductor alloys\AlAs-GaAs\Aspnes-70.0.yml	1	1	0.2066	0.8266	46
# 2554	other	AlAs-GaAs	Aspnes-80.4	semiconductor alloys\AlAs-GaAs\Aspnes-80.4.yml	1	1	0.2066	0.8266	46
# 2555	other	AlAs-GaAs	Adachi-0.315	semiconductor alloys\AlAs-GaAs\Adachi-0.315.yml	1	1	0.20664	12.398	200
# 2556	other	AlAs-GaAs	Adachi-0.700	semiconductor alloys\AlAs-GaAs\Adachi-0.700.yml	1	1	0.20664	12.398	200
# 2557	other	AlSb-GaSb	Ferrini-0	semiconductor alloys\AlSb-GaSb\Ferrini-0.yml	1	1	0.207	2.48	56
# 2558	other	AlSb-GaSb	Ferrini-10	semiconductor alloys\AlSb-GaSb\Ferrini-10.yml	1	1	0.207	2.48	56
# 2559	other	AlSb-GaSb	Ferrini-30	semiconductor alloys\AlSb-GaSb\Ferrini-30.yml	1	1	0.207	2.48	56
# 2560	other	AlSb-GaSb	Ferrini-50	semiconductor alloys\AlSb-GaSb\Ferrini-50.yml	1	1	0.207	2.48	56
# 2561	other	AlN-Al2O3	Hartnett-6.69	semiconductor alloys\AlN-Al2O3\Hartnett-6.69.yml	1	0	0.24	5.6	100
# 2562	other	AlN-Al2O3	Hartnett-5.88	semiconductor alloys\AlN-Al2O3\Hartnett-5.88.yml	1	1	0.24	5.6	12
# 2563	other	AlN-Al2O3	Hartnett-6.53	semiconductor alloys\AlN-Al2O3\Hartnett-6.53.yml	1	1	0.24	5.6	12
# 2564	other	AlN-Al2O3	Hartnett-7.17	semiconductor alloys\AlN-Al2O3\Hartnett-7.17.yml	1	1	0.24	5.6	12
# 2565	other	GaAs-InAs	Adachi	semiconductor alloys\GaAs-InAs\Adachi.yml	1	1	0.20664	12.398	200
# 2566	other	GaP-InP	Schubert	semiconductor alloys\GaP-InP\Schubert.yml	1	1	0.24961	0.95395	98
# 2567	other	GaAs-InAs-GaP-InP	Adachi	semiconductor alloys\GaAs-InAs-GaP-InP\Adachi.yml	1	1	0.20664	12.398	200
# 2568	other	Si-Ge	Jellison-11	semiconductor alloys\Si-Ge\Jellison-11.yml	1	1	0.24	0.84	103
# 2569	other	Si-Ge	Jellison-20	semiconductor alloys\Si-Ge\Jellison-20.yml	1	1	0.24	0.84	103
# 2570	other	Si-Ge	Jellison-28	semiconductor alloys\Si-Ge\Jellison-28.yml	1	1	0.24	0.84	103
# 2571	other	Si-Ge	Jellison-48	semiconductor alloys\Si-Ge\Jellison-48.yml	1	1	0.24	0.84	103
# 2572	other	Si-Ge	Jellison-47	semiconductor alloys\Si-Ge\Jellison-47.yml	1	1	0.24	0.84	103
# 2573	other	Si-Ge	Jellison-65	semiconductor alloys\Si-Ge\Jellison-65.yml	1	1	0.24	0.84	103
# 2574	other	Si-Ge	Jellison-85	semiconductor alloys\Si-Ge\Jellison-85.yml	1	1	0.24	0.84	103
# 2575	other	Si-Ge	Jellison-98	semiconductor alloys\Si-Ge\Jellison-98.yml	1	1	0.24	0.84	103
# 2576	other	AuAl2	Supansomboon	intermetallics\AuAl2\Supansomboon.yml	1	1	0.3	1.32	35
# 2577	other	HfO2-Y2O3	Wood	mixed crystals\HfO2-Y2O3\Wood.yml	1	0	0.365	5.0	100
# 2578	other	In2O3-SnO2	Moerland	mixed crystals\In2O3-SnO2\Moerland.yml	1	1	0.401047791	0.99996106	381
# 2579	other	In2O3-SnO2	Konig	mixed crystals\In2O3-SnO2\Konig.yml	1	1	0.25157	1.0	474
# 2580	other	In2O3-SnO2	Konig-EMA	mixed crystals\In2O3-SnO2\Konig-EMA.yml	1	1	0.25157	1.0	474
# 2581	other	TlBr-TlCl	Hettner	mixed crystals\TlBr-TlCl\Hettner.yml	1	0	0.6	24.0	100
# 2582	other	TlBr-TlI	Rodney	mixed crystals\TlBr-TlI\Rodney.yml	1	0	0.577	39.38	100
# 2583	other	ZrO2-Y2O3	Wood	mixed crystals\ZrO2-Y2O3\Wood.yml	1	0	0.361	5.135	100
# 2584	other	Mg-LiTaO3	Moutzouris-o	doped crystals\Mg-LiTaO3\Moutzouris-o.yml	1	0	0.45	1.551	100
# 2585	other	Mg-LiTaO3	Moutzouris-e	doped crystals\Mg-LiTaO3\Moutzouris-e.yml	1	0	0.45	1.551	100
# 2586	other	Nb-RbTiOPO4	Carvajal-Î±	doped crystals\Nb-RbTiOPO4\Carvajal-alpha.yml	1	0	0.4	1.5	100
# 2587	other	Nb-RbTiOPO4	Carvajal-Î²	doped crystals\Nb-RbTiOPO4\Carvajal-beta.yml	1	0	0.4	1.5	100
# 2588	other	Nb-RbTiOPO4	Carvajal-Î³	doped crystals\Nb-RbTiOPO4\Carvajal-gamma.yml	1	0	0.4	1.5	100
# 2589	other	Al-ZnO	Treharne	doped crystals\Al-ZnO\Treharne.yml	1	1	0.3	0.9	101
# 2617	other	MLC-6608	Li-o	liquid crystals\MLC-6608\Li-o.yml	1	0	0.45	0.656	100
# 2618	other	MLC-6608	Li-e	liquid crystals\MLC-6608\Li-e.yml	1	0	0.45	0.656	100
# 2619	other	MLC-9200-000	Li-o	liquid crystals\MLC-9200-000\Li-o.yml	1	0	0.45	0.656	100
# 2620	other	MLC-9200-000	Li-e	liquid crystals\MLC-9200-000\Li-e.yml	1	0	0.45	0.656	100
# 2621	other	MLC-9200-100	Li-o	liquid crystals\MLC-9200-100\Li-o.yml	1	0	0.45	0.656	100
# 2622	other	MLC-9200-100	Li-e	liquid crystals\MLC-9200-100\Li-e.yml	1	0	0.45	0.656	100
# 2623	other	TL-216	Li-o	liquid crystals\TL-216\Li-o.yml	1	0	0.45	0.656	100
# 2624	other	TL-216	Li-e	liquid crystals\TL-216\Li-e.yml	1	0	0.45	0.656	100
# 2625	other	SiN	Vogt-1.91	anti-reflective coatings\SiN\Vogt-1.91.yml	1	1	0.25	1.7	146
# 2626	other	SiN	Vogt-2.09	anti-reflective coatings\SiN\Vogt-2.09.yml	1	1	0.25	1.7	146
# 2627	other	SiN	Vogt-2.13	anti-reflective coatings\SiN\Vogt-2.13.yml	1	1	0.25	1.7	146
# 2628	other	BK7_matching_liquid	Cargille	index-matching liquids\cargille\BK7_matching_liquid.yml	1	0	0.31	1.55	100
# 2629	other	fused_silica_matching_liquid	Cargille-06350	index-matching liquids\cargille\fused_silica_matching_liquid-06350.yml	1	0	0.225	1.55	100
# 2630	other	fused_silica_matching_liquid	Cargille-50350	index-matching liquids\cargille\fused_silica_matching_liquid-50350.yml	1	0	0.225	1.55	100
# 2631	other	acrylic_matching_liquid	Cargille	index-matching liquids\cargille\acrylic_matching_liquid.yml	1	0	0.31	1.55	100
# 2632	other	Leica_Type_F	Wang	immersion oils\Leica Type F\Wang.yml	0	1	1.2	1.9	351
# 2633	other	Olympus_IMMOIL-F30CC	Wang	immersion oils\Olympus IMMOIL-F30CC\Wang.yml	0	1	1.2	1.9	351
# 2634	other	Sigma_Aldrich_M5904	Wang	immersion oils\Sigma Aldrich M5904\Wang.yml	0	1	1.2	1.9	351
# 2635	other	Optical_adhesives	Norland_NOA61	other\optical adhesives\Norland NOA 61.yml	1	0	0.45	1.55	100
# 2636	other	pmma_resists	Microchem495	other\resists\Microchem 495.yml	1	0	0.2	1.1	100
# 2637	other	pmma_resists	Microchem950	other\resists\Microchem 950.yml	1	0	0.2	1.1	100
# 2638	other	copolymer_resists	Microchem85mEL	other\resists\Microchem 8.5 mEL.yml	1	0	0.2	1.1	100
# 2639	other	negative_tone_photoresists	MicroresistEpoCore	other\resists\Micro resist EpoCore.yml	1	0	0.45	1.55	100
# 2640	other	negative_tone_photoresists	MicroresistEpoClad	other\resists\Micro resist EpoClad.yml	1	0	0.45	1.55	100
# 2641	other	negative_tone_photoresists	Microchem_SU8_2000	other\resists\Microchem SU-8 2000.yml	1	0	0.32	0.8	100
# 2642	other	negative_tone_photoresists	Microchem_SU8_3000	other\resists\Microchem SU-8 3000.yml	1	0	0.32	1.7	100
# 2698	3d	crystals	salt	main\NaCl\Li.yml	1	0	0.2	30.0	100
# 2699	3d	crystals	sapphire	main\Al2O3\Malitson-o.yml	1	0	0.2	5.0	100
# 2700	3d	crystals	silicon	main\Si\Vuye-20C.yml	1	1	0.2638	0.8266	129
# 2701	3d	glass	BK7	glass\schott\N-BK7.yml	1	1	0.3	2.5	25
# 2702	3d	glass	BAF10	glass\schott\N-BAF10.yml	1	1	0.35	2.5	21
# 2703	3d	glass	soda-lime-clear	misc\soda-lime\Rubin-clear.yml	1	1	0.31	4.6	106
# 2704	3d	glass	soda-lime-bronze	misc\soda-lime\Rubin-bronze.yml	1	1	0.32	4.6	105
# 2705	3d	glass	soda-lime-grey	misc\soda-lime\Rubin-grey.yml	1	1	0.32	4.6	105
# 2706	3d	glass	soda-lime-green	misc\soda-lime\Rubin-green.yml	1	1	0.32	4.6	105
# 2707	3d	liquids	water	main\H2O\Hale.yml	1	1	0.2	200.0	169
# 2708	3d	liquids	acetone	organic\C3H6O - acetone\Rheims.yml	1	0	0.4765	0.83	100
# 2709	3d	liquids	benzene	organic\C6H6 - benzene\Moutzouris.yml	1	0	0.45	1.551	100
# 2710	3d	liquids	mercury	main\Hg\Inagaki.yml	1	1	0.06358	6.19921	76
# 2711	3d	misc	acetylene_soot	soots\acetylene soot\Dalzell.yml	1	1	0.4358	10.0	13
# 2712	3d	misc	propane_soot	soots\propane soot\Dalzell.yml	1	1	0.4358	10.0	13
# 2713	3d	misc	diesel_soot	soots\diesel soot\Querry-NMSU.yml	1	1	0.26	55.5556	304

# %% [markdown]
# ### Search pages by term

# %%
db.search_pages("otanicar")
# Out:
# 3 results found.
# pageid	shelf	book	page	filepath	hasrefractive	hasextinction	rangeMin	rangeMax	points
# 739	organic	ethylene_glycol	Otanicar	organic\C2H6O2 - ethylene glycol\Otanicar.yml	0	1	0.2	1.5	66
# 744	organic	propylene_glycol	Otanicar	organic\C3H8O2 - propylene glycol\Otanicar.yml	1	1	0.434	0.656	66
# 2647	other	TherminolVP-1	Otanicar	heat transfer fluids\Therminol VP-1\Otanicar.yml	0	1	0.2	1.5	66

# %% [markdown]
# ### Search pages by exact term

# %%
db.search_pages("au",exact=True)
# Out:
# 23 results found.
# pageid	shelf	book	page	filepath	hasrefractive	hasextinction	rangeMin	rangeMax	points
# 58	main	Au	Johnson	main\Au\Johnson.yml	1	1	0.1879	1.937	49
# 59	main	Au	McPeak	main\Au\McPeak.yml	1	1	0.3	1.7	141
# 60	main	Au	Babar	main\Au\Babar.yml	1	1	0.2066	12.4	69
# 61	main	Au	Olmon-ev	main\Au\Olmon-ev.yml	1	1	0.3	24.93	448
# 62	main	Au	Olmon-sc	main\Au\Olmon-sc.yml	1	1	0.3	24.93	448
# 63	main	Au	Olmon-ts	main\Au\Olmon-ts.yml	1	1	0.3	24.93	448
# 64	main	Au	Werner	main\Au\Werner.yml	1	1	0.017586	2.479684	150
# 65	main	Au	Windt	main\Au\Windt.yml	1	1	0.00236	0.12157	36
# 66	main	Au	Ordal	main\Au\Ordal.yml	1	1	0.667	286.0	52
# 67	main	Au	Hagemann	main\Au\Hagemann.yml	1	1	8.266e-06	248.0	149
# 68	main	Au	Hagemann-2	main\Au\Hagemann-2.yml	1	1	0.003542	0.8266	124
# 69	main	Au	Yakubovsky-25nm	main\Au\Yakubovsky-25nm.yml	1	1	0.3	2.0	171
# 70	main	Au	Yakubovsky-53nm	main\Au\Yakubovsky-53nm.yml	1	1	0.3	2.0	171
# 71	main	Au	Yakubovsky-117nm	main\Au\Yakubovsky-117nm.yml	1	1	0.3	2.0	171
# 72	main	Au	Ciesielski	main\Au\Ciesielski.yml	1	1	0.19077	20.912	333
# 73	main	Au	Ciesielski-Ge	main\Au\Ciesielski-Ge.yml	1	1	0.19077	20.912	333
# 74	main	Au	Lemarchand-3.96nm	main\Au\Lemarchand-3.96nm.yml	1	1	0.35	1.8	291
# 75	main	Au	Lemarchand-4.62nm	main\Au\Lemarchand-4.62nm.yml	1	1	0.35	1.8	291
# 76	main	Au	Lemarchand-5.77nm	main\Au\Lemarchand-5.77nm.yml	1	1	0.35	1.8	291
# 77	main	Au	Lemarchand-11.7nm	main\Au\Lemarchand-11.7nm.yml	1	1	0.35	1.8	291
# 78	main	Au	Rakic-BB	main\Au\Rakic-BB.yml	1	1	0.24797	6.1992	200
# 79	main	Au	Rakic-LD	main\Au\Rakic-LD.yml	1	1	0.24797	6.1992	200
# 80	main	Au	Werner-DFT	main\Au\Werner-DFT.yml	1	1	0.017586	2.479684	150

# %% [markdown]
# ### Search by PageId

# %%
db.search_id(1542)
# Out:
# pageid	shelf	book	page	filepath	hasrefractive	hasextinction	rangeMin	rangeMax	points
# 1542	glass	HIKARI-FK	J-FKH1	glass\hikari\J-FKH1.yml	1	1	0.365015	2.05809	33

# %% [markdown]
# ### Search materials by refractive index (*n*) interval

# %%
db.search_n(n=0.3,delta_n=.0001)
# Out:
# *Search n = 0.3 delta_n =  0.0001
# 17 results found.
# pageid|shelf|book|page|wavelength|n
# (8, 'main', 'Ag', 'Hagemann', 0.3351, 0.3)
# (10, 'main', 'Ag', 'Ciesielski-Ge', 0.42759, 0.3)
# (10, 'main', 'Ag', 'Ciesielski-Ge', 0.62, 0.3)
# (12, 'main', 'Ag', 'Rakic-BB', 1.243, 0.29998)
# (77, 'main', 'Au', 'Lemarchand-11.7nm', 0.705, 0.30001489)
# (169, 'main', 'Cu', 'Johnson', 0.6168, 0.3)
# (169, 'main', 'Cu', 'Johnson', 0.892, 0.3)
# (337, 'main', 'Nb', 'Golovashkin-4.2K', 2.5, 0.3)
# (472, 'main', 'Pb', 'Golovashkin-4.2K', 1.6, 0.3)
# (2522, 'other', 'Au-Ag', 'Rioux-Au70Ag30', 0.608, 0.29996)
# (2522, 'other', 'Au-Ag', 'Rioux-Au70Ag30', 0.676, 0.29992)
# (2524, 'other', 'Au-Ag', 'Rioux-Au50Ag50', 0.573, 0.30004)
# (2524, 'other', 'Au-Ag', 'Rioux-Au50Ag50', 0.637, 0.29994)
# (2525, 'other', 'Au-Ag', 'Rioux-Au40Ag60', 0.71, 0.29996)
# (2527, 'other', 'Au-Ag', 'Rioux-Au20Ag80', 0.928, 0.2999)
# (2530, 'other', 'Cu-Zn', 'Querry-Cu90Zn10', 0.74, 0.3)
# (2684, '3d', 'metals', 'silver', 1.243, 0.29998)

# %% [markdown]
# ### Search materials by extinction coefficient (*k*) interval

# %%
db.search_k(k=0.3,delta_k=.0001)
# Out:
# *Search k = 0.3 delta_k =  0.0001
# 27 results found.
# pageid|shelf|book|page|wavelength|k
# (8, 'main', 'Ag', 'Hagemann', 0.0253, 0.3)
# (120, 'main', 'C', 'Djurisic-e', 0.049565, 0.29993)
# (383, 'main', 'H2O', 'Warren-2008', 3.195, 0.3)
# (384, 'main', 'H2O', 'Warren-1984', 3.195, 0.3)
# (447, 'main', 'InP', 'Adachi', 0.60281, 0.29994)
# (511, 'main', 'CdS', 'Treharne', 0.46592328, 0.29994)
# (544, 'main', 'InSb', 'Adachi', 0.94243, 0.29999)
# (552, 'main', 'CdSe', 'Ninomiya-o', 0.64473, 0.30001)
# (652, 'main', 'Tm', 'Vidal-Dasilva', 0.032843493, 0.30004735)
# (2594, 'other', 'Cu-C12H4N4', 'Querry', 1.72, 0.3)
# (2594, 'other', 'Cu-C12H4N4', 'Querry', 1.73, 0.3)
# (2594, 'other', 'Cu-C12H4N4', 'Querry', 1.75, 0.3)
# (2594, 'other', 'Cu-C12H4N4', 'Querry', 1.76, 0.3)
# (2595, 'other', 'Li-C12H4N4', 'Querry', 2.04, 0.3)
# (2656, 'other', 'diesel_soot', 'Querry-NMSU', 0.76, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 1.58, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 1.6, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 2.8249, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 2.8409, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 2.8736, 0.3)
# (2657, 'other', 'diesel_soot', 'Querry-NMSU-heated', 2.907, 0.3)
# (2658, 'other', 'diesel_soot', 'Querry-UMKC', 4.3478, 0.3)
# (2658, 'other', 'diesel_soot', 'Querry-UMKC', 5.4348, 0.3)
# (2658, 'other', 'diesel_soot', 'Querry-UMKC', 5.7471, 0.3)
# (2658, 'other', 'diesel_soot', 'Querry-UMKC', 41.6667, 0.3)
# (2696, '3d', 'crystals', 'ice', 3.195, 0.3)
# (2713, '3d', 'misc', 'diesel_soot', 0.76, 0.3)

# %% [markdown]
# ### Search materials by *n,k* interval

# %%
db.search_nk(n=0.3, delta_n=0.1,k=0.3,delta_k=0.1)
# Out:
# *Search n = 0.3 delta_n = 0.1 k = 0.3 delta_k = 0.1
# 42 results found.
# pageid|shelf|book|page|wavelength|n|k
# (73, 'main', 'C', 'Djurisic-o', 0.042069, 0.399493, 0.262777)
# (73, 'main', 'C', 'Djurisic-o', 0.042126, 0.397854, 0.265747)
# (73, 'main', 'C', 'Djurisic-o', 0.042183, 0.396244, 0.26875)
# (73, 'main', 'C', 'Djurisic-o', 0.04224, 0.394662, 0.271782)
# (73, 'main', 'C', 'Djurisic-o', 0.042298, 0.39311, 0.274845)
# (73, 'main', 'C', 'Djurisic-o', 0.042355, 0.391588, 0.277937)
# (73, 'main', 'C', 'Djurisic-o', 0.042413, 0.390097, 0.281058)
# (73, 'main', 'C', 'Djurisic-o', 0.042471, 0.388638, 0.284207)
# (73, 'main', 'C', 'Djurisic-o', 0.042529, 0.387211, 0.287382)
# (73, 'main', 'C', 'Djurisic-o', 0.042588, 0.385817, 0.290584)
# (73, 'main', 'C', 'Djurisic-o', 0.042646, 0.384457, 0.293811)
# (73, 'main', 'C', 'Djurisic-o', 0.042705, 0.383131, 0.297063)
# (73, 'main', 'C', 'Djurisic-o', 0.042763, 0.38184, 0.300338)
# (73, 'main', 'C', 'Djurisic-o', 0.042822, 0.380584, 0.303635)
# (73, 'main', 'C', 'Djurisic-o', 0.042881, 0.379364, 0.306955)
# (73, 'main', 'C', 'Djurisic-o', 0.042941, 0.37818, 0.310295)
# (73, 'main', 'C', 'Djurisic-o', 0.043, 0.377032, 0.313655)
# (73, 'main', 'C', 'Djurisic-o', 0.043059, 0.375921, 0.317034)
# (73, 'main', 'C', 'Djurisic-o', 0.043119, 0.374848, 0.320431)
# (73, 'main', 'C', 'Djurisic-o', 0.043179, 0.373812, 0.323845)
# (73, 'main', 'C', 'Djurisic-o', 0.043239, 0.372813, 0.327275)
# (73, 'main', 'C', 'Djurisic-o', 0.043299, 0.371852, 0.330719)
# (73, 'main', 'C', 'Djurisic-o', 0.04336, 0.37093, 0.334178)
# (73, 'main', 'C', 'Djurisic-o', 0.04342, 0.370045, 0.337649)
# (73, 'main', 'C', 'Djurisic-o', 0.043481, 0.369199, 0.341133)
# (73, 'main', 'C', 'Djurisic-o', 0.043542, 0.368391, 0.344628)
# (73, 'main', 'C', 'Djurisic-o', 0.043603, 0.367621, 0.348132)
# (73, 'main', 'C', 'Djurisic-o', 0.043664, 0.366889, 0.351646)
# (73, 'main', 'C', 'Djurisic-o', 0.043726, 0.366195, 0.355167)
# (73, 'main', 'C', 'Djurisic-o', 0.043787, 0.365539, 0.358696)
# (73, 'main', 'C', 'Djurisic-o', 0.043849, 0.364921, 0.362231)
# (73, 'main', 'C', 'Djurisic-o', 0.043911, 0.364341, 0.365772)
# (73, 'main', 'C', 'Djurisic-o', 0.043973, 0.363798, 0.369317)
# (73, 'main', 'C', 'Djurisic-o', 0.044035, 0.363293, 0.372865)
# (73, 'main', 'C', 'Djurisic-o', 0.044098, 0.362824, 0.376416)
# (73, 'main', 'C', 'Djurisic-o', 0.04416, 0.362392, 0.379969)
# (73, 'main', 'C', 'Djurisic-o', 0.044223, 0.361996, 0.383522)
# (73, 'main', 'C', 'Djurisic-o', 0.044286, 0.361636, 0.387076)
# (73, 'main', 'C', 'Djurisic-o', 0.044349, 0.361312, 0.390629)
# (73, 'main', 'C', 'Djurisic-o', 0.044413, 0.361024, 0.394181)
# (73, 'main', 'C', 'Djurisic-o', 0.044476, 0.36077, 0.397731)
# (128, 'main', 'SrF2', 'Rodriguez-de_Marcos', 26.34640693, 0.330467574, 0.383771957)

# %% [markdown]
# ### Custom SQL search
# You can search for custom sql queries (at your own risk). The function prints the number of results, and returns a list with n-tuples ordered by the fields on the select statement. Check the Section 1.2 for the scheme.

# %%
#Get any page in main/Ag/ that its name contains a letter 'k'.
db.search_custom('select * from pages where shelf="main" and book="Ag" '+
                 'and page LIKE "%k%"')
# Out:
# 6 results found.
# [(2, 'main', 'Ag', 'McPeak', 'main\\Ag\\McPeak.yml', 1, 1, 0.3, 1.7, 141),
#  (9,
#   'main',
#   'Ag',
#   'Ciesielski',
#   'main\\Ag\\Ciesielski.yml',
#   1,
#   1,
#   0.19077,
#   20.912,
#   333),
#  (10,
#   'main',
#   'Ag',
#   'Ciesielski-Ge',
#   'main\\Ag\\Ciesielski-Ge.yml',
#   1,
#   1,
#   0.19077,
#   20.912,
#   333),
#  (11,
#   'main',
#   'Ag',
#   'Ciesielski-Ni',
#   'main\\Ag\\Ciesielski-Ni.yml',
#   1,
#   1,
#   0.19077,
#   15.811,
#   332),
#  (12,
#   'main',
#   'Ag',
#   'Rakic-BB',
#   'main\\Ag\\Rakic-BB.yml',
#   1,
#   1,
#   0.24797,
#   12.398,
#   200),
#  (13,
#   'main',
#   'Ag',
#   'Rakic-LD',
#   'main\\Ag\\Rakic-LD.yml',
#   1,
#   1,
#   0.24797,
#   12.398,
#   200)]

# %%
#Get the wavelength and extinction coefficient from the page with id 1 
#in the interval [0.3, 0.4].
db.search_custom('''select wave,coeff 
                    from extcoeff 
                    where pageid = 1 and wave between 0.3 and 0.4''')
# Out:
# 11 results found.
# [(0.3, 0.9126),
#  (0.31, 0.5192),
#  (0.32, 0.3334),
#  (0.33, 0.6779),
#  (0.34, 1.084),
#  (0.35, 1.341),
#  (0.36, 1.536),
#  (0.3699, 1.699),
#  (0.3799, 1.841),
#  (0.3899, 1.971),
#  (0.3999, 2.09)]

# %%
#Get the wavelength and refractive index from the page with id 1 
#in the interval [0.3, 0.4].
db.search_custom('''select wave,refindex 
                    from refractiveindex 
                    where pageid = 1 and wave between 0.3 and 0.4''')
# Out:
# 11 results found.
# [(0.3, 1.646857286),
#  (0.31, 1.455629699),
#  (0.32, 0.920058628),
#  (0.33, 0.233797996),
#  (0.34, 0.103893124),
#  (0.35, 0.07599858),
#  (0.36, 0.063180003),
#  (0.37, 0.056279242),
#  (0.38, 0.050752406),
#  (0.39, 0.048660415),
#  (0.4, 0.04572895)]

# %%
#Get the path of the yml file, wavelength, refractive index and extinction coefficient 
#of all the pages with info on wavelength = 0.301
db.search_custom('''select p.filepath, r.wave,refindex,coeff 
                    from refractiveindex r inner join extcoeff e on r.pageid = e.pageid 
                    and r.wave = e.wave inner join pages p on r.pageid = p.pageid
                    where r.wave = .301''')
# Out:
# 28 results found.
# [('main\\Co\\Johnson.yml', 0.301, 1.44, 2.25),
#  ('main\\Cr\\Johnson.yml', 0.301, 1.53, 2.34),
#  ('main\\Fe\\Johnson.yml', 0.301, 1.67, 2.0),
#  ('main\\Mn\\Johnson.yml', 0.301, 1.86, 2.19),
#  ('main\\Ni\\Johnson.yml', 0.301, 2.02, 2.18),
#  ('main\\Pd\\Johnson.yml', 0.301, 1.2, 2.29),
#  ('main\\Ti\\Johnson.yml', 0.301, 1.45, 2.46),
#  ('main\\V\\Johnson.yml', 0.301, 2.07, 2.95),
#  ('alloys\\Au-Ag\\Rioux-Au100Ag0.yml', 0.301, 1.60958, 1.92549),
#  ('alloys\\Au-Ag\\Rioux-Au90Ag10.yml', 0.301, 1.56306, 1.85315),
#  ('alloys\\Au-Ag\\Rioux-Au80Ag20.yml', 0.301, 1.52131, 1.78689),
#  ('alloys\\Au-Ag\\Rioux-Au70Ag30.yml', 0.301, 1.48332, 1.72633),
#  ('alloys\\Au-Ag\\Rioux-Au60Ag40.yml', 0.301, 1.44868, 1.67012),
#  ('alloys\\Au-Ag\\Rioux-Au50Ag50.yml', 0.301, 1.41765, 1.61551),
#  ('alloys\\Au-Ag\\Rioux-Au40Ag60.yml', 0.301, 1.39132, 1.55779),
#  ('alloys\\Au-Ag\\Rioux-Au30Ag70.yml', 0.301, 1.37194, 1.48921),
#  ('alloys\\Au-Ag\\Rioux-Au20Ag80.yml', 0.301, 1.36413, 1.39552),
#  ('alloys\\Au-Ag\\Rioux-Au10Ag90.yml', 0.301, 1.37929, 1.24231),
#  ('alloys\\Au-Ag\\Rioux-Au0Ag100.yml', 0.301, 1.45664, 0.89431),
#  ('alloys\\Ni-Fe\\Tikuisis_gold150nm.yml', 0.301, 1.3756, 2.2341),
#  ('alloys\\Ni-Fe\\Tikuisis_gold10nm.yml', 0.301, 1.4349, 2.2585),
#  ('alloys\\Ni-Fe\\Tikuisis_bare150nm.yml', 0.301, 1.5966, 2.3246),
#  ('alloys\\Ni-Fe\\Tikuisis_bare10nm.yml', 0.301, 1.5814, 2.9569),
#  ('perovskite\\CH3NH3PbI3\\Leguy.yml', 0.301, 1.7499, 0.9508),
#  ('perovskite\\CH3NH3PbI3\\Leguy-hydrated.yml', 0.301, 2.7371, 1.0209),
#  ('perovskite\\CH3NH3PbI3\\Ball.yml', 0.301, 1.48952, 0.8304),
#  ('main\\Fe\\Johnson.yml', 0.301, 1.67, 2.0),
#  ('main\\Ti\\Johnson.yml', 0.301, 1.45, 2.46)]

# %% [markdown]
# ## Get data in a numpy.array from a PageId

# %% [markdown]
# ### Get material refractive index

# %%
db.get_material_n_numpy(5)
# Out:
# Material main\Ag\Johnson.yml loaded.
# array([[ 0.1879,  1.07  ],
#        [ 0.1916,  1.1   ],
#        [ 0.1953,  1.12  ],
#        [ 0.1993,  1.14  ],
#        [ 0.2033,  1.15  ],
#        [ 0.2073,  1.18  ],
#        [ 0.2119,  1.2   ],
#        [ 0.2164,  1.22  ],
#        [ 0.2214,  1.25  ],
#        [ 0.2262,  1.26  ],
#        [ 0.2313,  1.28  ],
#        [ 0.2371,  1.28  ],
#        [ 0.2426,  1.3   ],
#        [ 0.249 ,  1.31  ],
#        [ 0.2551,  1.33  ],
#        [ 0.2616,  1.35  ],
#        [ 0.2689,  1.38  ],
#        [ 0.2761,  1.41  ],
#        [ 0.2844,  1.41  ],
#        [ 0.2924,  1.39  ],
#        [ 0.3009,  1.34  ],
#        [ 0.3107,  1.13  ],
#        [ 0.3204,  0.81  ],
#        [ 0.3315,  0.17  ],
#        [ 0.3425,  0.14  ],
#        [ 0.3542,  0.1   ],
#        [ 0.3679,  0.07  ],
#        [ 0.3815,  0.05  ],
#        [ 0.3974,  0.05  ],
#        [ 0.4133,  0.05  ],
#        [ 0.4305,  0.04  ],
#        [ 0.4509,  0.04  ],
#        [ 0.4714,  0.05  ],
#        [ 0.4959,  0.05  ],
#        [ 0.5209,  0.05  ],
#        [ 0.5486,  0.06  ],
#        [ 0.5821,  0.05  ],
#        [ 0.6168,  0.06  ],
#        [ 0.6595,  0.05  ],
#        [ 0.7045,  0.04  ],
#        [ 0.756 ,  0.03  ],
#        [ 0.8211,  0.04  ],
#        [ 0.892 ,  0.04  ],
#        [ 0.984 ,  0.04  ],
#        [ 1.088 ,  0.04  ],
#        [ 1.216 ,  0.09  ],
#        [ 1.393 ,  0.13  ],
#        [ 1.61  ,  0.15  ],
#        [ 1.937 ,  0.24  ]])

# %% [markdown]
# ### Get material extinction coefficients

# %%
db.get_material_k_numpy(5)
# Out:
# Material main\Ag\Johnson.yml loaded.
# array([[  0.1879,   1.212 ],
#        [  0.1916,   1.232 ],
#        [  0.1953,   1.255 ],
#        [  0.1993,   1.277 ],
#        [  0.2033,   1.296 ],
#        [  0.2073,   1.312 ],
#        [  0.2119,   1.325 ],
#        [  0.2164,   1.336 ],
#        [  0.2214,   1.342 ],
#        [  0.2262,   1.344 ],
#        [  0.2313,   1.357 ],
#        [  0.2371,   1.367 ],
#        [  0.2426,   1.378 ],
#        [  0.249 ,   1.389 ],
#        [  0.2551,   1.393 ],
#        [  0.2616,   1.387 ],
#        [  0.2689,   1.372 ],
#        [  0.2761,   1.331 ],
#        [  0.2844,   1.264 ],
#        [  0.2924,   1.161 ],
#        [  0.3009,   0.964 ],
#        [  0.3107,   0.616 ],
#        [  0.3204,   0.392 ],
#        [  0.3315,   0.829 ],
#        [  0.3425,   1.142 ],
#        [  0.3542,   1.419 ],
#        [  0.3679,   1.657 ],
#        [  0.3815,   1.864 ],
#        [  0.3974,   2.07  ],
#        [  0.4133,   2.275 ],
#        [  0.4305,   2.462 ],
#        [  0.4509,   2.657 ],
#        [  0.4714,   2.869 ],
#        [  0.4959,   3.093 ],
#        [  0.5209,   3.324 ],
#        [  0.5486,   3.586 ],
#        [  0.5821,   3.858 ],
#        [  0.6168,   4.152 ],
#        [  0.6595,   4.483 ],
#        [  0.7045,   4.838 ],
#        [  0.756 ,   5.242 ],
#        [  0.8211,   5.727 ],
#        [  0.892 ,   6.312 ],
#        [  0.984 ,   6.992 ],
#        [  1.088 ,   7.795 ],
#        [  1.216 ,   8.828 ],
#        [  1.393 ,  10.1   ],
#        [  1.61  ,  11.85  ],
#        [  1.937 ,  14.08  ]])

# %% [markdown]
# ### Get material data as CSV

# %%
db.get_material_csv(5)
# Out:
# Material main\Ag\Werner.yml loaded.
# Wrote 5,main,Ag,Werner(nk).csv

# %% [markdown]
# ### Get ALL CSVs *(Be careful)*

# %%
db.get_material_csv_all(outputfolder="all")
# Out:
# Processing 0
# Material main\Ag\Johnson.yml loaded.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16464/2783940728.py in <module>
# ----> 1 db.get_material_csv_all(outputfolder="all")
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in get_material_csv_all(self, outputfolder)
#     307         for id in allids:
#     308             print("Processing", id)
# --> 309             self.get_material_csv(pageid=id, output="", folder=outputfolder)
#     310
#     311     def _get_pages_columns(self):
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\dboperations.py in get_material_csv(self, pageid, output, folder)
#     296         if folder != "":
#     297             output = folder+os.sep+output
# --> 298         mat.to_csv(output)
#     299
#     300     def get_material_csv_all(self, outputfolder):
#
# ~\Documents\GitHub\refractiveindex.info-sqlite\refractivesqlite\material.py in to_csv(self, output)
#     173                 len(refr) == len(ext):
#     174             header = "wl,n,k\n"
# --> 175             output_f = open(output.replace(".csv", "(nk).csv"), 'w')
#     176             output_f.write(header)
#     177             for i in range(len(refr)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all\\0,main,Ag,Johnson(nk).csv'

# %% [markdown]
# ## Interact with materials
# You need to *load* a material to interact with it. Once loaded, you can make any number of operations with it.

# %% [markdown]
# ### Load material by Id

# %%
mat = db.get_material(2713)
# Out:
# Material soots\diesel soot\Querry-NMSU.yml loaded.

# %% [markdown]
# ### Get material info

# %%
print(mat.get_page_info())
# Out:
# OrderedDict([('pageid', 2713), ('shelf', '3d'), ('book', 'misc'), ('page', 'diesel_soot'), ('filepath', 'soots\\diesel soot\\Querry-NMSU.yml'), ('hasrefractive', 1), ('hasextinction', 1), ('rangeMin', 0.26), ('rangeMax', 55.5556), ('points', 304)])

# %% [markdown]
# ### Get all material refractive index data

# %%
import numpy as np
n = mat.get_complete_refractive()
print(n)
# Out:
# [[0.37, 1.8937553148794222], [0.48833333333333334, 1.82714685501874], [0.6066666666666667, 1.8023045147079744], [0.725, 1.7895825733868478], [0.8433333333333333, 1.7818945237096582], [0.9616666666666667, 1.7766864298292608], [1.08, 1.7728282855251802], [1.1983333333333333, 1.7697509293680829], [1.3166666666666667, 1.7671401781044909], [1.435, 1.764810129683994], [1.5533333333333332, 1.7626445282209706], [1.6716666666666669, 1.760567251816403], [1.79, 1.7585264407152232], [1.9083333333333332, 1.7564854881252594], [2.026666666666667, 1.7544176911476248], [2.145, 1.7523029510314339], [2.263333333333333, 1.7501256691438016], [2.381666666666667, 1.747873365749312], [2.5, 1.7455357493648165]]

# %% [markdown]
# ### Get all material refractive index data as a numpy array

# %%
import numpy as np
n = np.array(mat.get_complete_refractive())
print(n)
# Out:
# [[ 0.26    1.39  ]
#  [ 0.28    1.415 ]
#  [ 0.3     1.439 ]
#  [ 0.32    1.46  ]
#  [ 0.34    1.483 ]
#  [ 0.36    1.5   ]
#  [ 0.38    1.514 ]
#  [ 0.4     1.528 ]
#  [ 0.42    1.539 ]
#  [ 0.44    1.553 ]
#  [ 0.46    1.565 ]
#  [ 0.48    1.577 ]
#  [ 0.5     1.589 ]
#  [ 0.52    1.599 ]
#  [ 0.54    1.608 ]
#  [ 0.56    1.617 ]
#  [ 0.58    1.624 ]
#  [ 0.6     1.632 ]
#  [ 0.62    1.639 ]
#  [ 0.64    1.646 ]
#  [ 0.66    1.652 ]
#  [ 0.68    1.658 ]
#  [ 0.7     1.664 ]
#  [ 0.72    1.67  ]
#  [ 0.74    1.676 ]
#  [ 0.76    1.682 ]
#  [ 0.78    1.688 ]
#  [ 0.8     1.694 ]
#  [ 0.82    1.701 ]
#  [ 0.84    1.706 ]
#  [ 0.86    1.71  ]
#  [ 0.88    1.715 ]
#  [ 0.9     1.722 ]
#  [ 0.92    1.727 ]
#  [ 0.94    1.731 ]
#  [ 0.96    1.736 ]
#  [ 0.98    1.741 ]
#  [ 1.      1.746 ]
#  [ 1.02    1.75  ]
#  [ 1.04    1.755 ]
#  [ 1.06    1.759 ]
#  [ 1.08    1.763 ]
#  [ 1.1     1.768 ]
#  [ 1.12    1.772 ]
#  [ 1.14    1.776 ]
#  [ 1.16    1.78  ]
#  [ 1.18    1.785 ]
#  [ 1.2     1.789 ]
#  [ 1.22    1.793 ]
#  [ 1.24    1.797 ]
#  [ 1.26    1.801 ]
#  [ 1.28    1.805 ]
#  [ 1.3     1.809 ]
#  [ 1.32    1.812 ]
#  [ 1.34    1.816 ]
#  [ 1.36    1.82  ]
#  [ 1.38    1.824 ]
#  [ 1.4     1.827 ]
#  [ 1.42    1.831 ]
#  [ 1.44    1.835 ]
#  [ 1.46    1.838 ]
#  [ 1.48    1.841 ]
#  [ 1.5     1.844 ]
#  [ 1.52    1.848 ]
#  [ 1.54    1.852 ]
#  [ 1.56    1.855 ]
#  [ 1.58    1.858 ]
#  [ 1.6     1.861 ]
#  [ 1.62    1.864 ]
#  [ 1.64    1.867 ]
#  [ 1.66    1.87  ]
#  [ 1.68    1.873 ]
#  [ 1.7     1.876 ]
#  [ 1.72    1.879 ]
#  [ 1.74    1.882 ]
#  [ 1.76    1.885 ]
#  [ 1.78    1.888 ]
#  [ 1.8     1.891 ]
#  [ 1.82    1.893 ]
#  [ 1.84    1.896 ]
#  [ 1.86    1.898 ]
#  [ 1.88    1.9   ]
#  [ 1.9     1.903 ]
#  [ 1.92    1.905 ]
#  [ 1.94    1.907 ]
#  [ 1.96    1.909 ]
#  [ 1.98    1.912 ]
#  [ 2.      1.914 ]
#  [ 2.02    1.916 ]
#  [ 2.04    1.919 ]
#  [ 2.06    1.921 ]
#  [ 2.08    1.924 ]
#  [ 2.1     1.927 ]
#  [ 2.12    1.929 ]
#  [ 2.14    1.933 ]
#  [ 2.16    1.936 ]
#  [ 2.18    1.939 ]
#  [ 2.2     1.942 ]
#  [ 2.22    1.945 ]
#  [ 2.24    1.947 ]
#  [ 2.26    1.951 ]
#  [ 2.28    1.954 ]
#  [ 2.3     1.956 ]
#  [ 2.32    1.96  ]
#  [ 2.34    1.963 ]
#  [ 2.36    1.966 ]
#  [ 2.38    1.968 ]
#  [ 2.4     1.971 ]
#  [ 2.42    1.974 ]
#  [ 2.44    1.977 ]
#  [ 2.46    1.979 ]
#  [ 2.48    1.981 ]
#  [ 2.5     1.984 ]
#  [ 2.5126  1.985 ]
#  [ 2.5253  1.986 ]
#  [ 2.5381  1.985 ]
#  [ 2.551   1.988 ]
#  [ 2.5641  1.988 ]
#  [ 2.5773  1.989 ]
#  [ 2.5907  1.991 ]
#  [ 2.6042  1.992 ]
#  [ 2.6178  1.993 ]
#  [ 2.6316  1.995 ]
#  [ 2.6455  1.995 ]
#  [ 2.6596  1.997 ]
#  [ 2.6738  1.997 ]
#  [ 2.6882  2.    ]
#  [ 2.7027  2.    ]
#  [ 2.7174  2.002 ]
#  [ 2.7322  2.003 ]
#  [ 2.7473  2.003 ]
#  [ 2.7624  2.004 ]
#  [ 2.7778  2.006 ]
#  [ 2.7933  2.007 ]
#  [ 2.809   2.007 ]
#  [ 2.8249  2.011 ]
#  [ 2.8409  2.012 ]
#  [ 2.8571  2.012 ]
#  [ 2.8736  2.013 ]
#  [ 2.8902  2.014 ]
#  [ 2.907   2.014 ]
#  [ 2.924   2.015 ]
#  [ 2.9412  2.017 ]
#  [ 2.9586  2.021 ]
#  [ 2.9762  2.021 ]
#  [ 2.994   2.022 ]
#  [ 3.012   2.024 ]
#  [ 3.0303  2.025 ]
#  [ 3.0488  2.026 ]
#  [ 3.0675  2.026 ]
#  [ 3.0864  2.026 ]
#  [ 3.1056  2.028 ]
#  [ 3.125   2.03  ]
#  [ 3.1447  2.032 ]
#  [ 3.1646  2.032 ]
#  [ 3.1847  2.034 ]
#  [ 3.2051  2.035 ]
#  [ 3.2258  2.036 ]
#  [ 3.2468  2.037 ]
#  [ 3.268   2.039 ]
#  [ 3.2895  2.041 ]
#  [ 3.3113  2.043 ]
#  [ 3.3333  2.045 ]
#  [ 3.3557  2.048 ]
#  [ 3.3784  2.045 ]
#  [ 3.4014  2.047 ]
#  [ 3.4247  2.049 ]
#  [ 3.4483  2.05  ]
#  [ 3.4722  2.052 ]
#  [ 3.4965  2.053 ]
#  [ 3.5211  2.054 ]
#  [ 3.5461  2.056 ]
#  [ 3.5714  2.058 ]
#  [ 3.5971  2.059 ]
#  [ 3.6232  2.058 ]
#  [ 3.6496  2.062 ]
#  [ 3.6765  2.062 ]
#  [ 3.7037  2.063 ]
#  [ 3.7313  2.066 ]
#  [ 3.7594  2.067 ]
#  [ 3.7879  2.069 ]
#  [ 3.8168  2.071 ]
#  [ 3.8462  2.071 ]
#  [ 3.876   2.071 ]
#  [ 3.9063  2.075 ]
#  [ 3.937   2.076 ]
#  [ 3.9683  2.077 ]
#  [ 4.      2.076 ]
#  [ 4.0323  2.08  ]
#  [ 4.065   2.081 ]
#  [ 4.0984  2.082 ]
#  [ 4.1322  2.084 ]
#  [ 4.1667  2.086 ]
#  [ 4.2017  2.086 ]
#  [ 4.2373  2.089 ]
#  [ 4.2735  2.089 ]
#  [ 4.3103  2.09  ]
#  [ 4.3478  2.091 ]
#  [ 4.386   2.093 ]
#  [ 4.4248  2.093 ]
#  [ 4.4643  2.095 ]
#  [ 4.5045  2.096 ]
#  [ 4.5455  2.097 ]
#  [ 4.5872  2.098 ]
#  [ 4.6296  2.1   ]
#  [ 4.6729  2.1   ]
#  [ 4.717   2.102 ]
#  [ 4.7619  2.103 ]
#  [ 4.8077  2.103 ]
#  [ 4.8544  2.105 ]
#  [ 4.902   2.106 ]
#  [ 4.9505  2.108 ]
#  [ 5.      2.107 ]
#  [ 5.0505  2.115 ]
#  [ 5.102   2.118 ]
#  [ 5.1546  2.118 ]
#  [ 5.2083  2.12  ]
#  [ 5.2632  2.122 ]
#  [ 5.3191  2.122 ]
#  [ 5.3763  2.124 ]
#  [ 5.4348  2.123 ]
#  [ 5.4945  2.123 ]
#  [ 5.5556  2.125 ]
#  [ 5.618   2.122 ]
#  [ 5.6818  2.123 ]
#  [ 5.7471  2.121 ]
#  [ 5.814   2.119 ]
#  [ 5.8824  2.12  ]
#  [ 5.9524  2.12  ]
#  [ 6.0241  2.115 ]
#  [ 6.0976  2.114 ]
#  [ 6.1728  2.115 ]
#  [ 6.25    2.122 ]
#  [ 6.3291  2.133 ]
#  [ 6.4103  2.141 ]
#  [ 6.4935  2.145 ]
#  [ 6.5789  2.146 ]
#  [ 6.6667  2.146 ]
#  [ 6.7568  2.146 ]
#  [ 6.8493  2.148 ]
#  [ 6.9444  2.154 ]
#  [ 7.0423  2.16  ]
#  [ 7.1429  2.162 ]
#  [ 7.2464  2.165 ]
#  [ 7.3529  2.17  ]
#  [ 7.4627  2.173 ]
#  [ 7.5758  2.179 ]
#  [ 7.6923  2.185 ]
#  [ 7.8125  2.192 ]
#  [ 7.9365  2.202 ]
#  [ 8.0645  2.21  ]
#  [ 8.1967  2.217 ]
#  [ 8.3333  2.225 ]
#  [ 8.4746  2.234 ]
#  [ 8.6207  2.244 ]
#  [ 8.7719  2.254 ]
#  [ 8.9286  2.261 ]
#  [ 9.0909  2.269 ]
#  [ 9.2593  2.274 ]
#  [ 9.434   2.277 ]
#  [ 9.6154  2.283 ]
#  [ 9.8039  2.289 ]
#  [10.      2.292 ]
#  [10.2041  2.295 ]
#  [10.4167  2.296 ]
#  [10.6383  2.294 ]
#  [10.8696  2.29  ]
#  [11.1111  2.288 ]
#  [11.3636  2.3   ]
#  [11.6279  2.307 ]
#  [11.9048  2.307 ]
#  [12.1951  2.321 ]
#  [12.5     2.334 ]
#  [12.8205  2.333 ]
#  [13.1579  2.342 ]
#  [13.5135  2.37  ]
#  [13.8889  2.378 ]
#  [14.2857  2.379 ]
#  [14.7059  2.383 ]
#  [15.1515  2.386 ]
#  [15.625   2.388 ]
#  [16.129   2.412 ]
#  [16.6667  2.425 ]
#  [17.2414  2.435 ]
#  [17.8571  2.444 ]
#  [18.5185  2.449 ]
#  [19.2308  2.454 ]
#  [20.      2.461 ]
#  [20.8333  2.47  ]
#  [21.7391  2.482 ]
#  [22.7273  2.494 ]
#  [23.8095  2.508 ]
#  [25.      2.519 ]
#  [26.3158  2.533 ]
#  [27.7778  2.546 ]
#  [29.4118  2.564 ]
#  [31.25    2.583 ]
#  [33.3333  2.597 ]
#  [35.7143  2.612 ]
#  [38.4615  2.631 ]
#  [41.6667  2.66  ]
#  [45.4545  2.697 ]
#  [50.      2.731 ]
#  [55.5556  2.754 ]]

# %% [markdown]
# ### Get all material extinction coefficient data

# %%
k = mat.get_complete_extinction()
print(k)
# Out:
.334], [3.3113, 0.333], [3.3333, 0.333], [3.3557, 0.33], [3.3784, 0.329], [3.4014, 0.333], [3.4247, 0.331], [3.4483, 0.332], [3.4722, 0.331], [3.4965, 0.329], [3.5211, 0.33], [3.5461, 0.33], [3.5714, 0.331], [3.5971, 0.328], [3.6232, 0.329], [3.6496, 0.329], [3.6765, 0.328], [3.7037, 0.328], [3.7313, 0.328], [3.7594, 0.328], [3.7879, 0.328], [3.8168, 0.327], [3.8462, 0.325], [3.876, 0.326], [3.9063, 0.326], [3.937, 0.326], [3.9683, 0.325], [4.0, 0.326], [4.0323, 0.326], [4.065, 0.324], [4.0984, 0.324], [4.1322, 0.325], [4.1667, 0.322], [4.2017, 0.323], [4.2373, 0.322], [4.2735, 0.321], [4.3103, 0.321], [4.3478, 0.322], [4.386, 0.32], [4.4248, 0.321], [4.4643, 0.321], [4.5045, 0.32], [4.5455, 0.32], [4.5872, 0.321], [4.6296, 0.321], [4.6729, 0.321], [4.717, 0.322], [4.7619, 0.321], [4.8077, 0.321], [4.8544, 0.321], [4.902, 0.322], [4.9505, 0.321], [5.0, 0.327], [5.0505, 0.328], [5.102, 0.324], [5.1546, 0.323], [5.2083, 0.322], [5.2632, 0.32], [5.3191, 0.319], [5.3763, 0.319], [5.4348, 0.318], [5.4945, 0.318], [5.5556, 0.316], [5.618, 0.317], [5.6818, 0.317], [5.7471, 0.316], [5.814, 0.32], [5.8824, 0.323], [5.9524, 0.323], [6.0241, 0.326], [6.0976, 0.333], [6.1728, 0.343], [6.25, 0.353], [6.3291, 0.356], [6.4103, 0.354], [6.4935, 0.351], [6.5789, 0.349], [6.6667, 0.35], [6.7568, 0.353], [6.8493, 0.359], [6.9444, 0.363], [7.0423, 0.365], [7.1429, 0.365], [7.2464, 0.369], [7.3529, 0.372], [7.4627, 0.376], [7.5758, 0.38], [7.6923, 0.383], [7.8125, 0.389], [7.9365, 0.391], [8.0645, 0.391], [8.1967, 0.392], [8.3333, 0.393 ...

# %% [markdown]
# ### Get all material extinction coefficient data as a numpy array

# %%
import numpy as np
k = np.array(mat.get_complete_extinction())
print(k)
# Out:
# [[ 0.26    0.171 ]
#  [ 0.28    0.189 ]
#  [ 0.3     0.205 ]
#  [ 0.32    0.22  ]
#  [ 0.34    0.23  ]
#  [ 0.36    0.236 ]
#  [ 0.38    0.243 ]
#  [ 0.4     0.249 ]
#  [ 0.42    0.255 ]
#  [ 0.44    0.262 ]
#  [ 0.46    0.266 ]
#  [ 0.48    0.272 ]
#  [ 0.5     0.273 ]
#  [ 0.52    0.275 ]
#  [ 0.54    0.277 ]
#  [ 0.56    0.279 ]
#  [ 0.58    0.281 ]
#  [ 0.6     0.283 ]
#  [ 0.62    0.285 ]
#  [ 0.64    0.287 ]
#  [ 0.66    0.289 ]
#  [ 0.68    0.291 ]
#  [ 0.7     0.293 ]
#  [ 0.72    0.295 ]
#  [ 0.74    0.298 ]
#  [ 0.76    0.3   ]
#  [ 0.78    0.302 ]
#  [ 0.8     0.304 ]
#  [ 0.82    0.305 ]
#  [ 0.84    0.306 ]
#  [ 0.86    0.308 ]
#  [ 0.88    0.311 ]
#  [ 0.9     0.312 ]
#  [ 0.92    0.313 ]
#  [ 0.94    0.314 ]
#  [ 0.96    0.315 ]
#  [ 0.98    0.317 ]
#  [ 1.      0.318 ]
#  [ 1.02    0.319 ]
#  [ 1.04    0.32  ]
#  [ 1.06    0.321 ]
#  [ 1.08    0.323 ]
#  [ 1.1     0.324 ]
#  [ 1.12    0.325 ]
#  [ 1.14    0.326 ]
#  [ 1.16    0.327 ]
#  [ 1.18    0.328 ]
#  [ 1.2     0.329 ]
#  [ 1.22    0.33  ]
#  [ 1.24    0.331 ]
#  [ 1.26    0.331 ]
#  [ 1.28    0.332 ]
#  [ 1.3     0.333 ]
#  [ 1.32    0.334 ]
#  [ 1.34    0.335 ]
#  [ 1.36    0.335 ]
#  [ 1.38    0.336 ]
#  [ 1.4     0.336 ]
#  [ 1.42    0.337 ]
#  [ 1.44    0.337 ]
#  [ 1.46    0.338 ]
#  [ 1.48    0.338 ]
#  [ 1.5     0.338 ]
#  [ 1.52    0.339 ]
#  [ 1.54    0.339 ]
#  [ 1.56    0.34  ]
#  [ 1.58    0.34  ]
#  [ 1.6     0.34  ]
#  [ 1.62    0.341 ]
#  [ 1.64    0.341 ]
#  [ 1.66    0.341 ]
#  [ 1.68    0.342 ]
#  [ 1.7     0.342 ]
#  [ 1.72    0.343 ]
#  [ 1.74    0.343 ]
#  [ 1.76    0.343 ]
#  [ 1.78    0.343 ]
#  [ 1.8     0.343 ]
#  [ 1.82    0.343 ]
#  [ 1.84    0.343 ]
#  [ 1.86    0.343 ]
#  [ 1.88    0.343 ]
#  [ 1.9     0.343 ]
#  [ 1.92    0.344 ]
#  [ 1.94    0.344 ]
#  [ 1.96    0.345 ]
#  [ 1.98    0.345 ]
#  [ 2.      0.346 ]
#  [ 2.02    0.347 ]
#  [ 2.04    0.347 ]
#  [ 2.06    0.348 ]
#  [ 2.08    0.349 ]
#  [ 2.1     0.35  ]
#  [ 2.12    0.351 ]
#  [ 2.14    0.351 ]
#  [ 2.16    0.352 ]
#  [ 2.18    0.352 ]
#  [ 2.2     0.352 ]
#  [ 2.22    0.353 ]
#  [ 2.24    0.353 ]
#  [ 2.26    0.353 ]
#  [ 2.28    0.353 ]
#  [ 2.3     0.353 ]
#  [ 2.32    0.353 ]
#  [ 2.34    0.352 ]
#  [ 2.36    0.352 ]
#  [ 2.38    0.351 ]
#  [ 2.4     0.351 ]
#  [ 2.42    0.35  ]
#  [ 2.44    0.349 ]
#  [ 2.46    0.348 ]
#  [ 2.48    0.347 ]
#  [ 2.5     0.346 ]
#  [ 2.5126  0.346 ]
#  [ 2.5253  0.343 ]
#  [ 2.5381  0.345 ]
#  [ 2.551   0.344 ]
#  [ 2.5641  0.343 ]
#  [ 2.5773  0.343 ]
#  [ 2.5907  0.343 ]
#  [ 2.6042  0.342 ]
#  [ 2.6178  0.343 ]
#  [ 2.6316  0.342 ]
#  [ 2.6455  0.342 ]
#  [ 2.6596  0.341 ]
#  [ 2.6738  0.342 ]
#  [ 2.6882  0.341 ]
#  [ 2.7027  0.34  ]
#  [ 2.7174  0.34  ]
#  [ 2.7322  0.339 ]
#  [ 2.7473  0.339 ]
#  [ 2.7624  0.339 ]
#  [ 2.7778  0.34  ]
#  [ 2.7933  0.338 ]
#  [ 2.809   0.339 ]
#  [ 2.8249  0.34  ]
#  [ 2.8409  0.337 ]
#  [ 2.8571  0.337 ]
#  [ 2.8736  0.337 ]
#  [ 2.8902  0.336 ]
#  [ 2.907   0.337 ]
#  [ 2.924   0.337 ]
#  [ 2.9412  0.339 ]
#  [ 2.9586  0.337 ]
#  [ 2.9762  0.336 ]
#  [ 2.994   0.335 ]
#  [ 3.012   0.338 ]
#  [ 3.0303  0.334 ]
#  [ 3.0488  0.333 ]
#  [ 3.0675  0.333 ]
#  [ 3.0864  0.335 ]
#  [ 3.1056  0.334 ]
#  [ 3.125   0.335 ]
#  [ 3.1447  0.334 ]
#  [ 3.1646  0.333 ]
#  [ 3.1847  0.334 ]
#  [ 3.2051  0.332 ]
#  [ 3.2258  0.333 ]
#  [ 3.2468  0.334 ]
#  [ 3.268   0.333 ]
#  [ 3.2895  0.334 ]
#  [ 3.3113  0.333 ]
#  [ 3.3333  0.333 ]
#  [ 3.3557  0.33  ]
#  [ 3.3784  0.329 ]
#  [ 3.4014  0.333 ]
#  [ 3.4247  0.331 ]
#  [ 3.4483  0.332 ]
#  [ 3.4722  0.331 ]
#  [ 3.4965  0.329 ]
#  [ 3.5211  0.33  ]
#  [ 3.5461  0.33  ]
#  [ 3.5714  0.331 ]
#  [ 3.5971  0.328 ]
#  [ 3.6232  0.329 ]
#  [ 3.6496  0.329 ]
#  [ 3.6765  0.328 ]
#  [ 3.7037  0.328 ]
#  [ 3.7313  0.328 ]
#  [ 3.7594  0.328 ]
#  [ 3.7879  0.328 ]
#  [ 3.8168  0.327 ]
#  [ 3.8462  0.325 ]
#  [ 3.876   0.326 ]
#  [ 3.9063  0.326 ]
#  [ 3.937   0.326 ]
#  [ 3.9683  0.325 ]
#  [ 4.      0.326 ]
#  [ 4.0323  0.326 ]
#  [ 4.065   0.324 ]
#  [ 4.0984  0.324 ]
#  [ 4.1322  0.325 ]
#  [ 4.1667  0.322 ]
#  [ 4.2017  0.323 ]
#  [ 4.2373  0.322 ]
#  [ 4.2735  0.321 ]
#  [ 4.3103  0.321 ]
#  [ 4.3478  0.322 ]
#  [ 4.386   0.32  ]
#  [ 4.4248  0.321 ]
#  [ 4.4643  0.321 ]
#  [ 4.5045  0.32  ]
#  [ 4.5455  0.32  ]
#  [ 4.5872  0.321 ]
#  [ 4.6296  0.321 ]
#  [ 4.6729  0.321 ]
#  [ 4.717   0.322 ]
#  [ 4.7619  0.321 ]
#  [ 4.8077  0.321 ]
#  [ 4.8544  0.321 ]
#  [ 4.902   0.322 ]
#  [ 4.9505  0.321 ]
#  [ 5.      0.327 ]
#  [ 5.0505  0.328 ]
#  [ 5.102   0.324 ]
#  [ 5.1546  0.323 ]
#  [ 5.2083  0.322 ]
#  [ 5.2632  0.32  ]
#  [ 5.3191  0.319 ]
#  [ 5.3763  0.319 ]
#  [ 5.4348  0.318 ]
#  [ 5.4945  0.318 ]
#  [ 5.5556  0.316 ]
#  [ 5.618   0.317 ]
#  [ 5.6818  0.317 ]
#  [ 5.7471  0.316 ]
#  [ 5.814   0.32  ]
#  [ 5.8824  0.323 ]
#  [ 5.9524  0.323 ]
#  [ 6.0241  0.326 ]
#  [ 6.0976  0.333 ]
#  [ 6.1728  0.343 ]
#  [ 6.25    0.353 ]
#  [ 6.3291  0.356 ]
#  [ 6.4103  0.354 ]
#  [ 6.4935  0.351 ]
#  [ 6.5789  0.349 ]
#  [ 6.6667  0.35  ]
#  [ 6.7568  0.353 ]
#  [ 6.8493  0.359 ]
#  [ 6.9444  0.363 ]
#  [ 7.0423  0.365 ]
#  [ 7.1429  0.365 ]
#  [ 7.2464  0.369 ]
#  [ 7.3529  0.372 ]
#  [ 7.4627  0.376 ]
#  [ 7.5758  0.38  ]
#  [ 7.6923  0.383 ]
#  [ 7.8125  0.389 ]
#  [ 7.9365  0.391 ]
#  [ 8.0645  0.391 ]
#  [ 8.1967  0.392 ]
#  [ 8.3333  0.393 ]
#  [ 8.4746  0.393 ]
#  [ 8.6207  0.394 ]
#  [ 8.7719  0.389 ]
#  [ 8.9286  0.386 ]
#  [ 9.0909  0.381 ]
#  [ 9.2593  0.376 ]
#  [ 9.434   0.374 ]
#  [ 9.6154  0.373 ]
#  [ 9.8039  0.367 ]
#  [10.      0.363 ]
#  [10.2041  0.358 ]
#  [10.4167  0.355 ]
#  [10.6383  0.351 ]
#  [10.8696  0.353 ]
#  [11.1111  0.362 ]
#  [11.3636  0.373 ]
#  [11.6279  0.366 ]
#  [11.9048  0.375 ]
#  [12.1951  0.382 ]
#  [12.5     0.377 ]
#  [12.8205  0.376 ]
#  [13.1579  0.391 ]
#  [13.5135  0.39  ]
#  [13.8889  0.373 ]
#  [14.2857  0.368 ]
#  [14.7059  0.367 ]
#  [15.1515  0.367 ]
#  [15.625   0.378 ]
#  [16.129   0.383 ]
#  [16.6667  0.373 ]
#  [17.2414  0.368 ]
#  [17.8571  0.361 ]
#  [18.5185  0.357 ]
#  [19.2308  0.354 ]
#  [20.      0.355 ]
#  [20.8333  0.357 ]
#  [21.7391  0.357 ]
#  [22.7273  0.356 ]
#  [23.8095  0.354 ]
#  [25.      0.353 ]
#  [26.3158  0.351 ]
#  [27.7778  0.349 ]
#  [29.4118  0.349 ]
#  [31.25    0.342 ]
#  [33.3333  0.336 ]
#  [35.7143  0.334 ]
#  [38.4615  0.334 ]
#  [41.6667  0.333 ]
#  [45.4545  0.323 ]
#  [50.      0.295 ]
#  [55.5556  0.264 ]]

# %% [markdown]
# ### Get material data as CSV

# %%
mat.to_csv(output="mat1.csv")
# Out:
# Wrote mat1(nk).csv

# %% [markdown]
# ###  Get refractive index at a specified wavelength

# %%
mat.get_refractiveindex(451)
# Out:
# array(1.84816136)

# %% [markdown]
# ### Get extinction coefficient at a specified wavelength

# %%
mat.get_extinctioncoefficient(451)
# Out:
# array(1.6382625e-07)
